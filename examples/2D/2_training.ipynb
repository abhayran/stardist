# %% [markdown]
# **In case of problems or questions, please first check the list of [Frequently Asked Questions (FAQ)](https://stardist.net/docs/faq.html).**
#
# Please shutdown all other training/prediction notebooks before running this notebook (as those might occupy the GPU memory otherwise).

# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import sys
import os
import numpy as np
import matplotlib
matplotlib.rcParams["image.interpolation"] = None
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from glob import glob
from tqdm import tqdm
from tifffile import imread
from csbdeep.utils import Path, normalize

from stardist import fill_label_holes, random_label_cmap, calculate_extents, gputools_available
from stardist.matching import matching, matching_dataset
from stardist.models import Config2D, StarDist2D, StarDistData2D

np.random.seed(42)
lbl_cmap = random_label_cmap()
# Out:
# /tmp/ipykernel_1372974/900461155.py:6: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   matplotlib.rcParams["image.interpolation"] = None
# 2023-03-23 20:16:41.530951: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Data
#
# We assume that data has already been downloaded via notebook [1_data.ipynb](1_data.ipynb).
#
# <div class="alert alert-block alert-info">
# Training data (for input `X` with associated label masks `Y`) can be provided via lists of numpy arrays, where each image can have a different size. Alternatively, a single numpy array can also be used if all images have the same size.
# Input images can either be two-dimensional (single-channel) or three-dimensional (multi-channel) arrays, where the channel axis comes last. Label images need to be integer-valued.
# </div>

# %%
def read_in_data(root: str):
    X = sorted(glob(f'{root}/images/*.tif'))
    Y = sorted(glob(f'{root}/masks/*.tif'))
    assert all(Path(x).name==Path(y).name for x,y in zip(X,Y))
    X = list(map(imread,X))
    Y = list(map(imread,Y))
    n_channel = 1 if X[0].ndim == 2 else X[0].shape[-1]
    
    axis_norm = (0,1)   # normalize channels independently
    # axis_norm = (0,1,2) # normalize channels jointly
    if n_channel > 1:
        print("Normalizing image channels %s." % ('jointly' if axis_norm is None or 2 in axis_norm else 'independently'))
        sys.stdout.flush()
    X = [normalize(x,1,99.8,axis=axis_norm) for x in tqdm(X)]
    Y = [fill_label_holes(y) for y in tqdm(Y)]
    return X, Y

# %%
X_trn, Y_trn = read_in_data("data/lizard/train")
X_val, Y_val = read_in_data("data/lizard/test")
# Out:
# Normalizing image channels independently.
# 100%|██████████| 710/710 [00:04<00:00, 170.81it/s]
# 100%|██████████| 710/710 [00:00<00:00, 1404.42it/s]
# Normalizing image channels independently.
# 100%|██████████| 174/174 [00:00<00:00, 177.07it/s]
# 100%|██████████| 174/174 [00:00<00:00, 1601.84it/s]

# %%
print(f"number of images: {len(X_trn) + len(X_val)}")
print(f"- training      : {len(X_trn)}")
print(f"- validation    : {len(X_val)}")
# Out:
# number of images: 884
# - training      : 710
# - validation    : 174

# %%
def plot_img_label(img, lbl, img_title="image", lbl_title="label", **kwargs):
    fig, (ai,al) = plt.subplots(1,2, figsize=(12,5), gridspec_kw=dict(width_ratios=(1.25,1)))
    im = ai.imshow(img, cmap='gray', clim=(0,1))
    ai.set_title(img_title)    
    fig.colorbar(im, ax=ai)
    al.imshow(lbl, cmap=lbl_cmap)
    al.set_title(lbl_title)
    plt.tight_layout()

# %%
i = min(9, len(X_trn)-1)
img, lbl = X_trn[i], Y_trn[i]
assert img.ndim in (2,3)
img = img if (img.ndim==2 or img.shape[-1]==3) else img[...,0]
plot_img_label(img,lbl)
None;
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Configuration
#
# A `StarDist2D` model is specified via a `Config2D` object.

# %%
print(Config2D.__doc__)
# Out:
# Configuration for a :class:`StarDist2D` model.
#
#     Parameters
#     ----------
#     axes : str or None
#         Axes of the input images.
#     n_rays : int
#         Number of radial directions for the star-convex polygon.
#         Recommended to use a power of 2 (default: 32).
#     n_channel_in : int
#         Number of channels of given input image (default: 1).
#     grid : (int,int)
#         Subsampling factors (must be powers of 2) for each of the axes.
#         Model will predict on a subsampled grid for increased efficiency and larger field of view.
#     n_classes : None or int
#         Number of object classes to use for multi-class predection (use None to disable)
#     backbone : str
#         Name of the neural network architecture to be used as backbone.
#     kwargs : dict
#         Overwrite (or add) configuration attributes (see below).
#
#
#     Attributes
#     ----------
#     unet_n_depth : int
#         Number of U-Net resolution levels (down/up-sampling layers).
#     unet_kernel_size : (int,int)
#         Convolution kernel size for all (U-Net) convolution layers.
#     unet_n_filter_base : int
#         Number of convolution kernels (feature channels) for first U-Net layer.
#         Doubled after each down-sampling layer.
#     unet_pool : (int,int)
#         Maxpooling size for all (U-Net) convolution layers.
#     net_conv_after_unet : int
#         Number of filters of the extra convolution layer after U-Net (0 to disable).
#     unet_* : *
#         Additional parameters for U-net backbone.
#     train_shape_completion : bool
#         Train model to predict complete shapes for partially visible objects at image boundary.
#     train_completion_crop : int
#         If 'train_shape_completion' is set to True, specify number of pixels to crop at boundary of training patches.
#         Should be chosen based on (largest) object sizes.
#     train_patch_size : (int,int)
#         Size of patches to be cropped from provided training images.
#     train_background_reg : float
#         Regularizer to encourage distance predictions on background regions to be 0.
#     train_foreground_only : float
#         Fraction (0..1) of patches that will only be sampled from regions that contain foreground pixels.
#     train_sample_cache : bool
#         Activate caching of valid patch regions for all training images (disable to save memory for large datasets)
#     train_dist_loss : str
#         Training loss for star-convex polygon distances ('mse' or 'mae').
#     train_loss_weights : tuple of float
#         Weights for losses relating to (probability, distance)
#     train_epochs : int
#         Number of training epochs.
#     train_steps_per_epoch : int
#         Number of parameter update steps per epoch.
#     train_learning_rate : float
#         Learning rate for training.
#     train_batch_size : int
#         Batch size for training.
#     train_n_val_patches : int
#         Number of patches to be extracted from validation images (``None`` = one patch per image).
#     train_tensorboard : bool
#         Enable TensorBoard for monitoring training progress.
#     train_reduce_lr : dict
#         Parameter :class:`dict` of ReduceLROnPlateau_ callback; set to ``None`` to disable.
#     use_gpu : bool
#         Indicate that the data generator should use OpenCL to do computations on the GPU.
#
#         .. _ReduceLROnPlateau: https://keras.io/api/callbacks/reduce_lr_on_plateau/

# %%
# 32 is a good default choice (see 1_data.ipynb)
n_rays = 32

# Use OpenCL-based computations for data generator during training (requires 'gputools')
use_gpu = False and gputools_available()

# Predict on subsampled grid for increased efficiency and larger field of view
grid = (2,2)

conf = Config2D (
    n_rays       = n_rays,
    grid         = grid,
    use_gpu      = False,
    n_channel_in = 3,
)
print(conf)
vars(conf)
# Out:
# Config2D(axes='YXC', backbone='unet', grid=(2, 2), n_channel_in=3, n_channel_out=33, n_classes=None, n_dim=2, n_rays=32, net_conv_after_unet=128, net_input_shape=(None, None, 3), net_mask_shape=(None, None, 1), train_background_reg=0.0001, train_batch_size=4, train_checkpoint='weights_best.h5', train_checkpoint_epoch='weights_now.h5', train_checkpoint_last='weights_last.h5', train_class_weights=(1, 1), train_completion_crop=32, train_dist_loss='mae', train_epochs=400, train_foreground_only=0.9, train_learning_rate=0.0003, train_loss_weights=(1, 0.2), train_n_val_patches=None, train_patch_size=(256, 256), train_reduce_lr={'factor': 0.5, 'patience': 40, 'min_delta': 0}, train_sample_cache=True, train_shape_completion=False, train_steps_per_epoch=100, train_tensorboard=True, unet_activation='relu', unet_batch_norm=False, unet_dropout=0.0, unet_kernel_size=(3, 3), unet_last_activation='relu', unet_n_conv_per_depth=2, unet_n_depth=3, unet_n_filter_base=32, unet_pool=(2, 2), unet_prefix='', use_gpu=False)
# {'n_dim': 2,
#  'axes': 'YXC',
#  'n_channel_in': 3,
#  'n_channel_out': 33,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'n_rays': 32,
#  'grid': (2, 2),
#  'backbone': 'unet',
#  'n_classes': None,
#  'unet_n_depth': 3,
#  'unet_kernel_size': (3, 3),
#  'unet_n_filter_base': 32,
#  'unet_n_conv_per_depth': 2,
#  'unet_pool': (2, 2),
#  'unet_activation': 'relu',
#  'unet_last_activation': 'relu',
#  'unet_batch_norm': False,
#  'unet_dropout': 0.0,
#  'unet_prefix': '',
#  'net_conv_after_unet': 128,
#  'net_input_shape': (None, None, 3),
#  'net_mask_shape': (None, None, 1),
#  'train_shape_completion': False,
#  'train_completion_crop': 32,
#  'train_patch_size': (256, 256),
#  'train_background_reg': 0.0001,
#  'train_foreground_only': 0.9,
#  'train_sample_cache': True,
#  'train_dist_loss': 'mae',
#  'train_loss_weights': (1, 0.2),
#  'train_class_weights': (1, 1),
#  'train_epochs': 400,
#  'train_steps_per_epoch': 100,
#  'train_learning_rate': 0.0003,
#  'train_batch_size': 4,
#  'train_n_val_patches': None,
#  'train_tensorboard': True,
#  'train_reduce_lr': {'factor': 0.5, 'patience': 40, 'min_delta': 0},
#  'use_gpu': False}

# %%
if use_gpu:
    from csbdeep.utils.tf import limit_gpu_memory
    # adjust as necessary: limit GPU memory to be used by TensorFlow to leave some to OpenCL-based computations
    limit_gpu_memory(0.8)
    # alternatively, try this:
    # limit_gpu_memory(None, allow_growth=True)

# %% [markdown]
# **Note:** The trained `StarDist2D` model will *not* predict completed shapes for partially visible objects at the image boundary if `train_shape_completion=False` (which is the default option).

# %%
model = StarDist2D(conf, name='stardist', basedir='models')
# Out:
# base_model.py (149): output path for model already exists, files may be overwritten: /dss/dsshome1/09/ge59gew2/stardist/examples/2D/models/stardist
# 2023-03-23 20:16:51.094034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18372 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 3g.20gb, pci bus id: 0000:90:00.0, compute capability: 8.0
# Using default values: prob_thresh=0.5, nms_thresh=0.4.

# %% [markdown]
# Check if the neural network has a large enough field of view to see up to the boundary of most objects.

# %%
median_size = calculate_extents(list(Y_trn), np.median)
fov = np.array(model._axes_tile_overlap('YX'))
print(f"median object size:      {median_size}")
print(f"network field of view :  {fov}")
if any(median_size > fov):
    print("WARNING: median object size larger than field of view of the neural network.")
# Out:
# 2023-03-23 20:16:52.169869: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8700
# 1/1 [==============================] - 1s 818ms/step
# 1/1 [==============================] - 0s 22ms/step
# median object size:      [10. 10.]
# network field of view :  [94 94]
# 2023-03-23 20:16:52.710602: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# You can define a function/callable that applies augmentation to each batch of the data generator.
# We here use an `augmenter` that applies random rotations, flips, and intensity changes, which are typically sensible for (2D) microscopy images (but you can disable augmentation by setting `augmenter = None`).

# %%
def random_fliprot(img, mask): 
    assert img.ndim >= mask.ndim
    axes = tuple(range(mask.ndim))
    perm = tuple(np.random.permutation(axes))
    img = img.transpose(perm + tuple(range(mask.ndim, img.ndim))) 
    mask = mask.transpose(perm) 
    for ax in axes: 
        if np.random.rand() > 0.5:
            img = np.flip(img, axis=ax)
            mask = np.flip(mask, axis=ax)
    return img, mask 

def random_intensity_change(img):
    img = img*np.random.uniform(0.6,2) + np.random.uniform(-0.2,0.2)
    return img


def augmenter(x, y):
    """Augmentation of a single input/label image pair.
    x is an input image
    y is the corresponding ground-truth label image
    """
    x, y = random_fliprot(x, y)
    x = random_intensity_change(x)
    # add some gaussian noise
    sig = 0.02*np.random.uniform(0,1)
    x = x + sig*np.random.normal(0,1,x.shape)
    return x, y

# %%
# plot some augmented examples
img, lbl = X_trn[0],Y_trn[0]
plot_img_label(img, lbl)
for _ in range(3):
    img_aug, lbl_aug = augmenter(img,lbl)
    plot_img_label(img_aug, lbl_aug, img_title="image augmented", lbl_title="label augmented")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Training

# %% [markdown]
# We recommend to monitor the progress during training with [TensorBoard](https://www.tensorflow.org/programmers_guide/summaries_and_tensorboard). You can start it in the shell from the current working directory like this:
#
#     $ tensorboard --logdir=.
#
# Then connect to [http://localhost:6006/](http://localhost:6006/) with your browser.

# %%
quick_demo = False

if quick_demo:
    print (
        "NOTE: This is only for a quick demonstration!\n"
        "      Please set the variable 'quick_demo = False' for proper (long) training.",
        file=sys.stderr, flush=True
    )
    model.train(X_trn, Y_trn, validation_data=(X_val,Y_val), augmenter=augmenter,
                epochs=2, steps_per_epoch=10)

    print("====> Stopping training and loading previously trained demo model from disk.", file=sys.stderr, flush=True)
    model = StarDist2D.from_pretrained('2D_demo')
else:
    model.train(X_trn, Y_trn, validation_data=(X_val,Y_val), augmenter=augmenter)
None;
# Out:
# Epoch 1/400
# 2023-03-23 20:16:56.305948: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# WARNING:tensorflow:AutoGraph could not transform <function _gcd_import at 0x7f4c9b4e4430> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x7f4c9b4e4430>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _gcd_import at 0x7f4c9b4e4430> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x7f4c9b4e4430>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2023-03-23 20:17:01.125630: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f45968a27d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-03-23 20:17:01.125672: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB MIG 3g.20gb, Compute Capability 8.0
# 2023-03-23 20:17:01.130966: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-03-23 20:17:01.268318: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7176 - prob_loss: 0.0786 - dist_loss: 3.1947 - prob_kld: 0.0727 - dist_relevant_mae: 3.1944 - dist_relevant_mse: 17.2920 - dist_dist_iou_metric: 0.20
# 100/100 [==============================] - 16s 66ms/step - loss: 0.7159 - prob_loss: 0.0780 - dist_loss: 3.1898 - prob_kld: 0.0721 - dist_relevant_mae: 3.1895 - dist_relevant_mse: 17.2418 - dist_dist_iou_metric: 0.2062 - val_loss: 0.5481 - val_prob_loss: 0.0266 - val_dist_loss: 2.6073 - val_prob_kld: 0.0235 - val_dist_relevant_mae: 2.6070 - val_dist_relevant_mse: 11.6931 - val_dist_dist_iou_metric: 0.2267 - lr: 3.0000e-04
# Epoch 2/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5484 - prob_loss: 0.0265 - dist_loss: 2.6097 - prob_kld: 0.0234 - dist_relevant_mae: 2.6094 - dist_relevant_mse: 11.5014 - dist_dist_iou_metric: 0.31
# 100/100 [==============================] - 5s 47ms/step - loss: 0.5489 - prob_loss: 0.0266 - dist_loss: 2.6117 - prob_kld: 0.0234 - dist_relevant_mae: 2.6113 - dist_relevant_mse: 11.5174 - dist_dist_iou_metric: 0.3150 - val_loss: 0.5046 - val_prob_loss: 0.0321 - val_dist_loss: 2.3624 - val_prob_kld: 0.0289 - val_dist_relevant_mae: 2.3620 - val_dist_relevant_mse: 8.7239 - val_dist_dist_iou_metric: 0.3867 - lr: 3.0000e-04
# Epoch 3/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5330 - prob_loss: 0.0281 - dist_loss: 2.5245 - prob_kld: 0.0248 - dist_relevant_mae: 2.5241 - dist_relevant_mse: 10.6430 - dist_dist_iou_metric: 0.32
# 100/100 [==============================] - 4s 44ms/step - loss: 0.5334 - prob_loss: 0.0280 - dist_loss: 2.5270 - prob_kld: 0.0247 - dist_relevant_mae: 2.5266 - dist_relevant_mse: 10.6800 - dist_dist_iou_metric: 0.3243 - val_loss: 0.4824 - val_prob_loss: 0.0232 - val_dist_loss: 2.2961 - val_prob_kld: 0.0200 - val_dist_relevant_mae: 2.2957 - val_dist_relevant_mse: 8.8146 - val_dist_dist_iou_metric: 0.3491 - lr: 3.0000e-04
# Epoch 4/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5110 - prob_loss: 0.0270 - dist_loss: 2.4201 - prob_kld: 0.0234 - dist_relevant_mae: 2.4197 - dist_relevant_mse: 9.8280 - dist_dist_iou_metric: 0.36
# 100/100 [==============================] - 4s 43ms/step - loss: 0.5105 - prob_loss: 0.0268 - dist_loss: 2.4185 - prob_kld: 0.0233 - dist_relevant_mae: 2.4181 - dist_relevant_mse: 9.8071 - dist_dist_iou_metric: 0.3614 - val_loss: 0.4826 - val_prob_loss: 0.0234 - val_dist_loss: 2.2961 - val_prob_kld: 0.0202 - val_dist_relevant_mae: 2.2957 - val_dist_relevant_mse: 8.2899 - val_dist_dist_iou_metric: 0.4019 - lr: 3.0000e-04
# Epoch 5/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4913 - prob_loss: 0.0222 - dist_loss: 2.3455 - prob_kld: 0.0192 - dist_relevant_mae: 2.3451 - dist_relevant_mse: 9.2896 - dist_dist_iou_metric: 0.36
# 100/100 [==============================] - 4s 44ms/step - loss: 0.4906 - prob_loss: 0.0222 - dist_loss: 2.3424 - prob_kld: 0.0191 - dist_relevant_mae: 2.3420 - dist_relevant_mse: 9.2692 - dist_dist_iou_metric: 0.3700 - val_loss: 0.4379 - val_prob_loss: 0.0246 - val_dist_loss: 2.0668 - val_prob_kld: 0.0214 - val_dist_relevant_mae: 2.0664 - val_dist_relevant_mse: 7.1926 - val_dist_dist_iou_metric: 0.4214 - lr: 3.0000e-04
# Epoch 6/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4221 - prob_loss: 0.0238 - dist_loss: 1.9914 - prob_kld: 0.0204 - dist_relevant_mae: 1.9910 - dist_relevant_mse: 7.1802 - dist_dist_iou_metric: 0.44
# 100/100 [==============================] - 4s 43ms/step - loss: 0.4216 - prob_loss: 0.0238 - dist_loss: 1.9889 - prob_kld: 0.0204 - dist_relevant_mae: 1.9885 - dist_relevant_mse: 7.1589 - dist_dist_iou_metric: 0.4455 - val_loss: 0.3610 - val_prob_loss: 0.0212 - val_dist_loss: 1.6991 - val_prob_kld: 0.0180 - val_dist_relevant_mae: 1.6987 - val_dist_relevant_mse: 4.8232 - val_dist_dist_iou_metric: 0.5405 - lr: 3.0000e-04
# Epoch 7/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3605 - prob_loss: 0.0209 - dist_loss: 1.6976 - prob_kld: 0.0177 - dist_relevant_mae: 1.6972 - dist_relevant_mse: 5.4173 - dist_dist_iou_metric: 0.51
# 100/100 [==============================] - 4s 43ms/step - loss: 0.3596 - prob_loss: 0.0208 - dist_loss: 1.6938 - prob_kld: 0.0176 - dist_relevant_mae: 1.6934 - dist_relevant_mse: 5.3940 - dist_dist_iou_metric: 0.5139 - val_loss: 0.3187 - val_prob_loss: 0.0190 - val_dist_loss: 1.4988 - val_prob_kld: 0.0158 - val_dist_relevant_mae: 1.4985 - val_dist_relevant_mse: 4.2770 - val_dist_dist_iou_metric: 0.5383 - lr: 3.0000e-04
# Epoch 8/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3547 - prob_loss: 0.0199 - dist_loss: 1.6738 - prob_kld: 0.0166 - dist_relevant_mae: 1.6735 - dist_relevant_mse: 5.3681 - dist_dist_iou_metric: 0.52
# 100/100 [==============================] - 4s 45ms/step - loss: 0.3540 - prob_loss: 0.0198 - dist_loss: 1.6709 - prob_kld: 0.0165 - dist_relevant_mae: 1.6705 - dist_relevant_mse: 5.3468 - dist_dist_iou_metric: 0.5231 - val_loss: 0.3007 - val_prob_loss: 0.0179 - val_dist_loss: 1.4137 - val_prob_kld: 0.0147 - val_dist_relevant_mae: 1.4133 - val_dist_relevant_mse: 3.6852 - val_dist_dist_iou_metric: 0.5842 - lr: 3.0000e-04
# Epoch 9/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3323 - prob_loss: 0.0187 - dist_loss: 1.5682 - prob_kld: 0.0155 - dist_relevant_mae: 1.5678 - dist_relevant_mse: 4.7724 - dist_dist_iou_metric: 0.54
# 100/100 [==============================] - 5s 47ms/step - loss: 0.3337 - prob_loss: 0.0188 - dist_loss: 1.5745 - prob_kld: 0.0156 - dist_relevant_mae: 1.5741 - dist_relevant_mse: 4.8304 - dist_dist_iou_metric: 0.5448 - val_loss: 0.2972 - val_prob_loss: 0.0184 - val_dist_loss: 1.3941 - val_prob_kld: 0.0152 - val_dist_relevant_mae: 1.3938 - val_dist_relevant_mse: 3.6873 - val_dist_dist_iou_metric: 0.5787 - lr: 3.0000e-04
# Epoch 10/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3289 - prob_loss: 0.0179 - dist_loss: 1.5549 - prob_kld: 0.0148 - dist_relevant_mae: 1.5546 - dist_relevant_mse: 4.8099 - dist_dist_iou_metric: 0.55
# 100/100 [==============================] - 4s 43ms/step - loss: 0.3309 - prob_loss: 0.0179 - dist_loss: 1.5652 - prob_kld: 0.0148 - dist_relevant_mae: 1.5648 - dist_relevant_mse: 4.8820 - dist_dist_iou_metric: 0.5569 - val_loss: 0.2991 - val_prob_loss: 0.0182 - val_dist_loss: 1.4044 - val_prob_kld: 0.0150 - val_dist_relevant_mae: 1.4041 - val_dist_relevant_mse: 3.7088 - val_dist_dist_iou_metric: 0.5758 - lr: 3.0000e-04
# Epoch 11/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3242 - prob_loss: 0.0196 - dist_loss: 1.5231 - prob_kld: 0.0161 - dist_relevant_mae: 1.5227 - dist_relevant_mse: 4.5920 - dist_dist_iou_metric: 0.55
# 100/100 [==============================] - 4s 44ms/step - loss: 0.3246 - prob_loss: 0.0196 - dist_loss: 1.5249 - prob_kld: 0.0161 - dist_relevant_mae: 1.5246 - dist_relevant_mse: 4.6011 - dist_dist_iou_metric: 0.5590 - val_loss: 0.2845 - val_prob_loss: 0.0188 - val_dist_loss: 1.3282 - val_prob_kld: 0.0156 - val_dist_relevant_mae: 1.3278 - val_dist_relevant_mse: 3.3173 - val_dist_dist_iou_metric: 0.6105 - lr: 3.0000e-04
# Epoch 12/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3217 - prob_loss: 0.0187 - dist_loss: 1.5151 - prob_kld: 0.0153 - dist_relevant_mae: 1.5147 - dist_relevant_mse: 4.5977 - dist_dist_iou_metric: 0.56
# 100/100 [==============================] - 4s 43ms/step - loss: 0.3235 - prob_loss: 0.0186 - dist_loss: 1.5245 - prob_kld: 0.0153 - dist_relevant_mae: 1.5241 - dist_relevant_mse: 4.6828 - dist_dist_iou_metric: 0.5646 - val_loss: 0.3014 - val_prob_loss: 0.0165 - val_dist_loss: 1.4244 - val_prob_kld: 0.0133 - val_dist_relevant_mae: 1.4239 - val_dist_relevant_mse: 3.5481 - val_dist_dist_iou_metric: 0.6066 - lr: 3.0000e-04
# Epoch 13/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3096 - prob_loss: 0.0169 - dist_loss: 1.4633 - prob_kld: 0.0140 - dist_relevant_mae: 1.4629 - dist_relevant_mse: 4.2512 - dist_dist_iou_metric: 0.57
# 100/100 [==============================] - 4s 44ms/step - loss: 0.3097 - prob_loss: 0.0170 - dist_loss: 1.4637 - prob_kld: 0.0140 - dist_relevant_mae: 1.4633 - dist_relevant_mse: 4.2510 - dist_dist_iou_metric: 0.5759 - val_loss: 0.2776 - val_prob_loss: 0.0164 - val_dist_loss: 1.3057 - val_prob_kld: 0.0132 - val_dist_relevant_mae: 1.3053 - val_dist_relevant_mse: 3.2917 - val_dist_dist_iou_metric: 0.6044 - lr: 3.0000e-04
# Epoch 14/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3154 - prob_loss: 0.0189 - dist_loss: 1.4826 - prob_kld: 0.0154 - dist_relevant_mae: 1.4822 - dist_relevant_mse: 4.5509 - dist_dist_iou_metric: 0.58
# 100/100 [==============================] - 4s 44ms/step - loss: 0.3150 - prob_loss: 0.0188 - dist_loss: 1.4810 - prob_kld: 0.0153 - dist_relevant_mae: 1.4806 - dist_relevant_mse: 4.5347 - dist_dist_iou_metric: 0.5809 - val_loss: 0.2865 - val_prob_loss: 0.0163 - val_dist_loss: 1.3511 - val_prob_kld: 0.0132 - val_dist_relevant_mae: 1.3506 - val_dist_relevant_mse: 3.3199 - val_dist_dist_iou_metric: 0.6190 - lr: 3.0000e-04
# Epoch 15/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3079 - prob_loss: 0.0181 - dist_loss: 1.4490 - prob_kld: 0.0148 - dist_relevant_mae: 1.4486 - dist_relevant_mse: 4.1571 - dist_dist_iou_metric: 0.58
# 100/100 [==============================] - 4s 43ms/step - loss: 0.3075 - prob_loss: 0.0181 - dist_loss: 1.4471 - prob_kld: 0.0148 - dist_relevant_mae: 1.4467 - dist_relevant_mse: 4.1438 - dist_dist_iou_metric: 0.5809 - val_loss: 0.2842 - val_prob_loss: 0.0173 - val_dist_loss: 1.3346 - val_prob_kld: 0.0141 - val_dist_relevant_mae: 1.3342 - val_dist_relevant_mse: 3.4563 - val_dist_dist_iou_metric: 0.5858 - lr: 3.0000e-04
# Epoch 16/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3131 - prob_loss: 0.0172 - dist_loss: 1.4798 - prob_kld: 0.0140 - dist_relevant_mae: 1.4794 - dist_relevant_mse: 4.5094 - dist_dist_iou_metric: 0.57
# 100/100 [==============================] - 5s 45ms/step - loss: 0.3131 - prob_loss: 0.0172 - dist_loss: 1.4798 - prob_kld: 0.0140 - dist_relevant_mae: 1.4794 - dist_relevant_mse: 4.5094 - dist_dist_iou_metric: 0.5778 - val_loss: 0.2679 - val_prob_loss: 0.0158 - val_dist_loss: 1.2607 - val_prob_kld: 0.0126 - val_dist_relevant_mae: 1.2603 - val_dist_relevant_mse: 3.1165 - val_dist_dist_iou_metric: 0.6204 - lr: 3.0000e-04
# Epoch 17/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3099 - prob_loss: 0.0178 - dist_loss: 1.4602 - prob_kld: 0.0145 - dist_relevant_mae: 1.4598 - dist_relevant_mse: 4.4995 - dist_dist_iou_metric: 0.58
# 100/100 [==============================] - 4s 43ms/step - loss: 0.3094 - prob_loss: 0.0179 - dist_loss: 1.4575 - prob_kld: 0.0146 - dist_relevant_mae: 1.4571 - dist_relevant_mse: 4.4802 - dist_dist_iou_metric: 0.5837 - val_loss: 0.2628 - val_prob_loss: 0.0157 - val_dist_loss: 1.2354 - val_prob_kld: 0.0126 - val_dist_relevant_mae: 1.2351 - val_dist_relevant_mse: 2.9810 - val_dist_dist_iou_metric: 0.6310 - lr: 3.0000e-04
# Epoch 18/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2840 - prob_loss: 0.0168 - dist_loss: 1.3358 - prob_kld: 0.0136 - dist_relevant_mae: 1.3355 - dist_relevant_mse: 3.6012 - dist_dist_iou_metric: 0.60
# 100/100 [==============================] - 4s 42ms/step - loss: 0.2841 - prob_loss: 0.0167 - dist_loss: 1.3370 - prob_kld: 0.0135 - dist_relevant_mae: 1.3366 - dist_relevant_mse: 3.6040 - dist_dist_iou_metric: 0.6081 - val_loss: 0.2632 - val_prob_loss: 0.0153 - val_dist_loss: 1.2396 - val_prob_kld: 0.0121 - val_dist_relevant_mae: 1.2392 - val_dist_relevant_mse: 3.0003 - val_dist_dist_iou_metric: 0.6339 - lr: 3.0000e-04
# Epoch 19/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2963 - prob_loss: 0.0171 - dist_loss: 1.3961 - prob_kld: 0.0138 - dist_relevant_mae: 1.3957 - dist_relevant_mse: 4.0303 - dist_dist_iou_metric: 0.59
# 100/100 [==============================] - 4s 42ms/step - loss: 0.2961 - prob_loss: 0.0171 - dist_loss: 1.3953 - prob_kld: 0.0138 - dist_relevant_mae: 1.3949 - dist_relevant_mse: 4.0220 - dist_dist_iou_metric: 0.5970 - val_loss: 0.2762 - val_prob_loss: 0.0151 - val_dist_loss: 1.3057 - val_prob_kld: 0.0119 - val_dist_relevant_mae: 1.3053 - val_dist_relevant_mse: 3.2434 - val_dist_dist_iou_metric: 0.5924 - lr: 3.0000e-04
# Epoch 20/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2939 - prob_loss: 0.0179 - dist_loss: 1.3800 - prob_kld: 0.0145 - dist_relevant_mae: 1.3796 - dist_relevant_mse: 3.8866 - dist_dist_iou_metric: 0.59
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2935 - prob_loss: 0.0179 - dist_loss: 1.3780 - prob_kld: 0.0145 - dist_relevant_mae: 1.3776 - dist_relevant_mse: 3.8708 - dist_dist_iou_metric: 0.5978 - val_loss: 0.2547 - val_prob_loss: 0.0150 - val_dist_loss: 1.1981 - val_prob_kld: 0.0119 - val_dist_relevant_mae: 1.1978 - val_dist_relevant_mse: 2.8627 - val_dist_dist_iou_metric: 0.6342 - lr: 3.0000e-04
# Epoch 21/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2986 - prob_loss: 0.0166 - dist_loss: 1.4100 - prob_kld: 0.0135 - dist_relevant_mae: 1.4097 - dist_relevant_mse: 4.1963 - dist_dist_iou_metric: 0.59
# 100/100 [==============================] - 5s 47ms/step - loss: 0.2985 - prob_loss: 0.0166 - dist_loss: 1.4093 - prob_kld: 0.0135 - dist_relevant_mae: 1.4090 - dist_relevant_mse: 4.1853 - dist_dist_iou_metric: 0.5966 - val_loss: 0.2678 - val_prob_loss: 0.0171 - val_dist_loss: 1.2537 - val_prob_kld: 0.0139 - val_dist_relevant_mae: 1.2533 - val_dist_relevant_mse: 3.0009 - val_dist_dist_iou_metric: 0.6439 - lr: 3.0000e-04
# Epoch 22/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2889 - prob_loss: 0.0175 - dist_loss: 1.3575 - prob_kld: 0.0141 - dist_relevant_mae: 1.3571 - dist_relevant_mse: 3.8476 - dist_dist_iou_metric: 0.60
# 100/100 [==============================] - 4s 42ms/step - loss: 0.2885 - prob_loss: 0.0174 - dist_loss: 1.3554 - prob_kld: 0.0141 - dist_relevant_mae: 1.3551 - dist_relevant_mse: 3.8332 - dist_dist_iou_metric: 0.6050 - val_loss: 0.2585 - val_prob_loss: 0.0149 - val_dist_loss: 1.2179 - val_prob_kld: 0.0117 - val_dist_relevant_mae: 1.2175 - val_dist_relevant_mse: 2.9171 - val_dist_dist_iou_metric: 0.6258 - lr: 3.0000e-04
# Epoch 23/400
# 3/3 [==============================] - 0s 12ms/step- loss: 0.2882 - prob_loss: 0.0172 - dist_loss: 1.3550 - prob_kld: 0.0138 - dist_relevant_mae: 1.3546 - dist_relevant_mse: 3.9082 - dist_dist_iou_metric: 0.60
# 100/100 [==============================] - 5s 47ms/step - loss: 0.2879 - prob_loss: 0.0171 - dist_loss: 1.3540 - prob_kld: 0.0138 - dist_relevant_mae: 1.3536 - dist_relevant_mse: 3.8993 - dist_dist_iou_metric: 0.6091 - val_loss: 0.2509 - val_prob_loss: 0.0150 - val_dist_loss: 1.1795 - val_prob_kld: 0.0118 - val_dist_relevant_mae: 1.1791 - val_dist_relevant_mse: 2.7271 - val_dist_dist_iou_metric: 0.6478 - lr: 3.0000e-04
# Epoch 24/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2786 - prob_loss: 0.0156 - dist_loss: 1.3152 - prob_kld: 0.0125 - dist_relevant_mae: 1.3148 - dist_relevant_mse: 3.6526 - dist_dist_iou_metric: 0.61
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2788 - prob_loss: 0.0155 - dist_loss: 1.3164 - prob_kld: 0.0125 - dist_relevant_mae: 1.3160 - dist_relevant_mse: 3.6628 - dist_dist_iou_metric: 0.6168 - val_loss: 0.2562 - val_prob_loss: 0.0151 - val_dist_loss: 1.2053 - val_prob_kld: 0.0119 - val_dist_relevant_mae: 1.2048 - val_dist_relevant_mse: 2.8294 - val_dist_dist_iou_metric: 0.6485 - lr: 3.0000e-04
# Epoch 25/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2880 - prob_loss: 0.0175 - dist_loss: 1.3529 - prob_kld: 0.0141 - dist_relevant_mae: 1.3525 - dist_relevant_mse: 3.8378 - dist_dist_iou_metric: 0.60
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2888 - prob_loss: 0.0175 - dist_loss: 1.3561 - prob_kld: 0.0141 - dist_relevant_mae: 1.3557 - dist_relevant_mse: 3.8609 - dist_dist_iou_metric: 0.6093 - val_loss: 0.2506 - val_prob_loss: 0.0151 - val_dist_loss: 1.1779 - val_prob_kld: 0.0119 - val_dist_relevant_mae: 1.1776 - val_dist_relevant_mse: 2.7213 - val_dist_dist_iou_metric: 0.6426 - lr: 3.0000e-04
# Epoch 26/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2844 - prob_loss: 0.0174 - dist_loss: 1.3350 - prob_kld: 0.0140 - dist_relevant_mae: 1.3346 - dist_relevant_mse: 3.7723 - dist_dist_iou_metric: 0.61
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2839 - prob_loss: 0.0173 - dist_loss: 1.3327 - prob_kld: 0.0139 - dist_relevant_mae: 1.3324 - dist_relevant_mse: 3.7556 - dist_dist_iou_metric: 0.6144 - val_loss: 0.2696 - val_prob_loss: 0.0149 - val_dist_loss: 1.2734 - val_prob_kld: 0.0117 - val_dist_relevant_mae: 1.2731 - val_dist_relevant_mse: 3.0927 - val_dist_dist_iou_metric: 0.5979 - lr: 3.0000e-04
# Epoch 27/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2782 - prob_loss: 0.0158 - dist_loss: 1.3117 - prob_kld: 0.0127 - dist_relevant_mae: 1.3113 - dist_relevant_mse: 3.7419 - dist_dist_iou_metric: 0.62
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2780 - prob_loss: 0.0159 - dist_loss: 1.3106 - prob_kld: 0.0127 - dist_relevant_mae: 1.3102 - dist_relevant_mse: 3.7357 - dist_dist_iou_metric: 0.6217 - val_loss: 0.2504 - val_prob_loss: 0.0157 - val_dist_loss: 1.1735 - val_prob_kld: 0.0125 - val_dist_relevant_mae: 1.1731 - val_dist_relevant_mse: 2.7100 - val_dist_dist_iou_metric: 0.6416 - lr: 3.0000e-04
# Epoch 28/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2751 - prob_loss: 0.0165 - dist_loss: 1.2930 - prob_kld: 0.0133 - dist_relevant_mae: 1.2926 - dist_relevant_mse: 3.6011 - dist_dist_iou_metric: 0.62
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2750 - prob_loss: 0.0167 - dist_loss: 1.2917 - prob_kld: 0.0134 - dist_relevant_mae: 1.2913 - dist_relevant_mse: 3.5939 - dist_dist_iou_metric: 0.6219 - val_loss: 0.2543 - val_prob_loss: 0.0148 - val_dist_loss: 1.1976 - val_prob_kld: 0.0116 - val_dist_relevant_mae: 1.1973 - val_dist_relevant_mse: 2.7944 - val_dist_dist_iou_metric: 0.6238 - lr: 3.0000e-04
# Epoch 29/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2709 - prob_loss: 0.0164 - dist_loss: 1.2722 - prob_kld: 0.0131 - dist_relevant_mae: 1.2718 - dist_relevant_mse: 3.4831 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2709 - prob_loss: 0.0164 - dist_loss: 1.2728 - prob_kld: 0.0131 - dist_relevant_mae: 1.2724 - dist_relevant_mse: 3.4797 - dist_dist_iou_metric: 0.6325 - val_loss: 0.2478 - val_prob_loss: 0.0145 - val_dist_loss: 1.1667 - val_prob_kld: 0.0113 - val_dist_relevant_mae: 1.1664 - val_dist_relevant_mse: 2.7115 - val_dist_dist_iou_metric: 0.6355 - lr: 3.0000e-04
# Epoch 30/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2726 - prob_loss: 0.0164 - dist_loss: 1.2809 - prob_kld: 0.0131 - dist_relevant_mae: 1.2805 - dist_relevant_mse: 3.5069 - dist_dist_iou_metric: 0.62
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2723 - prob_loss: 0.0163 - dist_loss: 1.2797 - prob_kld: 0.0130 - dist_relevant_mae: 1.2794 - dist_relevant_mse: 3.5001 - dist_dist_iou_metric: 0.6268 - val_loss: 0.2450 - val_prob_loss: 0.0147 - val_dist_loss: 1.1516 - val_prob_kld: 0.0115 - val_dist_relevant_mae: 1.1512 - val_dist_relevant_mse: 2.6324 - val_dist_dist_iou_metric: 0.6546 - lr: 3.0000e-04
# Epoch 31/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2708 - prob_loss: 0.0160 - dist_loss: 1.2739 - prob_kld: 0.0127 - dist_relevant_mae: 1.2735 - dist_relevant_mse: 3.4832 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 4s 42ms/step - loss: 0.2708 - prob_loss: 0.0160 - dist_loss: 1.2739 - prob_kld: 0.0127 - dist_relevant_mae: 1.2735 - dist_relevant_mse: 3.4832 - dist_dist_iou_metric: 0.6306 - val_loss: 0.2461 - val_prob_loss: 0.0148 - val_dist_loss: 1.1562 - val_prob_kld: 0.0117 - val_dist_relevant_mae: 1.1558 - val_dist_relevant_mse: 2.6867 - val_dist_dist_iou_metric: 0.6604 - lr: 3.0000e-04
# Epoch 32/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2740 - prob_loss: 0.0161 - dist_loss: 1.2896 - prob_kld: 0.0128 - dist_relevant_mae: 1.2892 - dist_relevant_mse: 3.6363 - dist_dist_iou_metric: 0.62
# 100/100 [==============================] - 5s 48ms/step - loss: 0.2740 - prob_loss: 0.0161 - dist_loss: 1.2896 - prob_kld: 0.0128 - dist_relevant_mae: 1.2892 - dist_relevant_mse: 3.6363 - dist_dist_iou_metric: 0.6245 - val_loss: 0.2438 - val_prob_loss: 0.0151 - val_dist_loss: 1.1435 - val_prob_kld: 0.0119 - val_dist_relevant_mae: 1.1431 - val_dist_relevant_mse: 2.5828 - val_dist_dist_iou_metric: 0.6557 - lr: 3.0000e-04
# Epoch 33/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2654 - prob_loss: 0.0165 - dist_loss: 1.2447 - prob_kld: 0.0132 - dist_relevant_mae: 1.2443 - dist_relevant_mse: 3.3308 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2651 - prob_loss: 0.0165 - dist_loss: 1.2430 - prob_kld: 0.0131 - dist_relevant_mae: 1.2426 - dist_relevant_mse: 3.3185 - dist_dist_iou_metric: 0.6369 - val_loss: 0.2394 - val_prob_loss: 0.0146 - val_dist_loss: 1.1240 - val_prob_kld: 0.0114 - val_dist_relevant_mae: 1.1237 - val_dist_relevant_mse: 2.5201 - val_dist_dist_iou_metric: 0.6659 - lr: 3.0000e-04
# Epoch 34/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2702 - prob_loss: 0.0155 - dist_loss: 1.2736 - prob_kld: 0.0123 - dist_relevant_mae: 1.2732 - dist_relevant_mse: 3.5363 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 4s 42ms/step - loss: 0.2703 - prob_loss: 0.0155 - dist_loss: 1.2738 - prob_kld: 0.0124 - dist_relevant_mae: 1.2735 - dist_relevant_mse: 3.5365 - dist_dist_iou_metric: 0.6302 - val_loss: 0.2442 - val_prob_loss: 0.0155 - val_dist_loss: 1.1437 - val_prob_kld: 0.0123 - val_dist_relevant_mae: 1.1433 - val_dist_relevant_mse: 2.6365 - val_dist_dist_iou_metric: 0.6674 - lr: 3.0000e-04
# Epoch 35/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2686 - prob_loss: 0.0166 - dist_loss: 1.2597 - prob_kld: 0.0132 - dist_relevant_mae: 1.2594 - dist_relevant_mse: 3.5057 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2679 - prob_loss: 0.0165 - dist_loss: 1.2570 - prob_kld: 0.0131 - dist_relevant_mae: 1.2566 - dist_relevant_mse: 3.4892 - dist_dist_iou_metric: 0.6346 - val_loss: 0.2431 - val_prob_loss: 0.0148 - val_dist_loss: 1.1414 - val_prob_kld: 0.0116 - val_dist_relevant_mae: 1.1411 - val_dist_relevant_mse: 2.5789 - val_dist_dist_iou_metric: 0.6485 - lr: 3.0000e-04
# Epoch 36/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2613 - prob_loss: 0.0164 - dist_loss: 1.2245 - prob_kld: 0.0129 - dist_relevant_mae: 1.2241 - dist_relevant_mse: 3.2453 - dist_dist_iou_metric: 0.64
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2615 - prob_loss: 0.0164 - dist_loss: 1.2251 - prob_kld: 0.0129 - dist_relevant_mae: 1.2248 - dist_relevant_mse: 3.2473 - dist_dist_iou_metric: 0.6427 - val_loss: 0.2440 - val_prob_loss: 0.0142 - val_dist_loss: 1.1490 - val_prob_kld: 0.0110 - val_dist_relevant_mae: 1.1487 - val_dist_relevant_mse: 2.7001 - val_dist_dist_iou_metric: 0.6677 - lr: 3.0000e-04
# Epoch 37/400
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2606 - prob_loss: 0.0151 - dist_loss: 1.2274 - prob_kld: 0.0121 - dist_relevant_mae: 1.2270 - dist_relevant_mse: 3.2844 - dist_dist_iou_metric: 0.64
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2608 - prob_loss: 0.0151 - dist_loss: 1.2282 - prob_kld: 0.0121 - dist_relevant_mae: 1.2278 - dist_relevant_mse: 3.2876 - dist_dist_iou_metric: 0.6407 - val_loss: 0.2341 - val_prob_loss: 0.0140 - val_dist_loss: 1.1005 - val_prob_kld: 0.0108 - val_dist_relevant_mae: 1.1002 - val_dist_relevant_mse: 2.4714 - val_dist_dist_iou_metric: 0.6595 - lr: 3.0000e-04
# Epoch 38/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2611 - prob_loss: 0.0155 - dist_loss: 1.2276 - prob_kld: 0.0124 - dist_relevant_mae: 1.2272 - dist_relevant_mse: 3.2000 - dist_dist_iou_metric: 0.64
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2602 - prob_loss: 0.0154 - dist_loss: 1.2236 - prob_kld: 0.0124 - dist_relevant_mae: 1.2232 - dist_relevant_mse: 3.1808 - dist_dist_iou_metric: 0.6439 - val_loss: 0.2372 - val_prob_loss: 0.0141 - val_dist_loss: 1.1155 - val_prob_kld: 0.0109 - val_dist_relevant_mae: 1.1151 - val_dist_relevant_mse: 2.5287 - val_dist_dist_iou_metric: 0.6671 - lr: 3.0000e-04
# Epoch 39/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2664 - prob_loss: 0.0164 - dist_loss: 1.2498 - prob_kld: 0.0130 - dist_relevant_mae: 1.2495 - dist_relevant_mse: 3.4874 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2664 - prob_loss: 0.0165 - dist_loss: 1.2492 - prob_kld: 0.0131 - dist_relevant_mae: 1.2488 - dist_relevant_mse: 3.4788 - dist_dist_iou_metric: 0.6386 - val_loss: 0.2482 - val_prob_loss: 0.0145 - val_dist_loss: 1.1685 - val_prob_kld: 0.0113 - val_dist_relevant_mae: 1.1681 - val_dist_relevant_mse: 2.6819 - val_dist_dist_iou_metric: 0.6644 - lr: 3.0000e-04
# Epoch 40/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2574 - prob_loss: 0.0155 - dist_loss: 1.2095 - prob_kld: 0.0123 - dist_relevant_mae: 1.2091 - dist_relevant_mse: 3.2023 - dist_dist_iou_metric: 0.64
# 100/100 [==============================] - 4s 45ms/step - loss: 0.2574 - prob_loss: 0.0155 - dist_loss: 1.2095 - prob_kld: 0.0123 - dist_relevant_mae: 1.2091 - dist_relevant_mse: 3.2023 - dist_dist_iou_metric: 0.6448 - val_loss: 0.2301 - val_prob_loss: 0.0137 - val_dist_loss: 1.0818 - val_prob_kld: 0.0105 - val_dist_relevant_mae: 1.0815 - val_dist_relevant_mse: 2.3800 - val_dist_dist_iou_metric: 0.6680 - lr: 3.0000e-04
# Epoch 41/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2657 - prob_loss: 0.0153 - dist_loss: 1.2518 - prob_kld: 0.0121 - dist_relevant_mae: 1.2514 - dist_relevant_mse: 3.4540 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2664 - prob_loss: 0.0152 - dist_loss: 1.2560 - prob_kld: 0.0120 - dist_relevant_mae: 1.2556 - dist_relevant_mse: 3.4877 - dist_dist_iou_metric: 0.6341 - val_loss: 0.2348 - val_prob_loss: 0.0138 - val_dist_loss: 1.1049 - val_prob_kld: 0.0107 - val_dist_relevant_mae: 1.1046 - val_dist_relevant_mse: 2.4548 - val_dist_dist_iou_metric: 0.6578 - lr: 3.0000e-04
# Epoch 42/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2572 - prob_loss: 0.0155 - dist_loss: 1.2087 - prob_kld: 0.0122 - dist_relevant_mae: 1.2084 - dist_relevant_mse: 3.1969 - dist_dist_iou_metric: 0.64
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2574 - prob_loss: 0.0156 - dist_loss: 1.2092 - prob_kld: 0.0123 - dist_relevant_mae: 1.2088 - dist_relevant_mse: 3.1944 - dist_dist_iou_metric: 0.6457 - val_loss: 0.2294 - val_prob_loss: 0.0144 - val_dist_loss: 1.0749 - val_prob_kld: 0.0112 - val_dist_relevant_mae: 1.0746 - val_dist_relevant_mse: 2.3575 - val_dist_dist_iou_metric: 0.6766 - lr: 3.0000e-04
# Epoch 43/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2560 - prob_loss: 0.0147 - dist_loss: 1.2064 - prob_kld: 0.0116 - dist_relevant_mae: 1.2060 - dist_relevant_mse: 3.1011 - dist_dist_iou_metric: 0.64
# 100/100 [==============================] - 5s 46ms/step - loss: 0.2560 - prob_loss: 0.0147 - dist_loss: 1.2064 - prob_kld: 0.0116 - dist_relevant_mae: 1.2060 - dist_relevant_mse: 3.1011 - dist_dist_iou_metric: 0.6461 - val_loss: 0.2370 - val_prob_loss: 0.0154 - val_dist_loss: 1.1079 - val_prob_kld: 0.0123 - val_dist_relevant_mae: 1.1076 - val_dist_relevant_mse: 2.4942 - val_dist_dist_iou_metric: 0.6663 - lr: 3.0000e-04
# Epoch 44/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2580 - prob_loss: 0.0162 - dist_loss: 1.2090 - prob_kld: 0.0129 - dist_relevant_mae: 1.2086 - dist_relevant_mse: 3.3073 - dist_dist_iou_metric: 0.64
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2577 - prob_loss: 0.0163 - dist_loss: 1.2067 - prob_kld: 0.0129 - dist_relevant_mae: 1.2063 - dist_relevant_mse: 3.2939 - dist_dist_iou_metric: 0.6498 - val_loss: 0.2284 - val_prob_loss: 0.0140 - val_dist_loss: 1.0718 - val_prob_kld: 0.0109 - val_dist_relevant_mae: 1.0714 - val_dist_relevant_mse: 2.3503 - val_dist_dist_iou_metric: 0.6742 - lr: 3.0000e-04
# Epoch 45/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2522 - prob_loss: 0.0163 - dist_loss: 1.1791 - prob_kld: 0.0129 - dist_relevant_mae: 1.1788 - dist_relevant_mse: 2.9914 - dist_dist_iou_metric: 0.64
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2524 - prob_loss: 0.0166 - dist_loss: 1.1793 - prob_kld: 0.0130 - dist_relevant_mae: 1.1790 - dist_relevant_mse: 2.9968 - dist_dist_iou_metric: 0.6483 - val_loss: 0.2365 - val_prob_loss: 0.0139 - val_dist_loss: 1.1127 - val_prob_kld: 0.0107 - val_dist_relevant_mae: 1.1124 - val_dist_relevant_mse: 2.4898 - val_dist_dist_iou_metric: 0.6482 - lr: 3.0000e-04
# Epoch 46/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2573 - prob_loss: 0.0143 - dist_loss: 1.2148 - prob_kld: 0.0112 - dist_relevant_mae: 1.2144 - dist_relevant_mse: 3.3722 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2587 - prob_loss: 0.0144 - dist_loss: 1.2217 - prob_kld: 0.0113 - dist_relevant_mae: 1.2214 - dist_relevant_mse: 3.4361 - dist_dist_iou_metric: 0.6497 - val_loss: 0.2335 - val_prob_loss: 0.0149 - val_dist_loss: 1.0930 - val_prob_kld: 0.0117 - val_dist_relevant_mae: 1.0926 - val_dist_relevant_mse: 2.4644 - val_dist_dist_iou_metric: 0.6776 - lr: 3.0000e-04
# Epoch 47/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2513 - prob_loss: 0.0148 - dist_loss: 1.1823 - prob_kld: 0.0116 - dist_relevant_mae: 1.1820 - dist_relevant_mse: 3.1561 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2510 - prob_loss: 0.0147 - dist_loss: 1.1814 - prob_kld: 0.0115 - dist_relevant_mae: 1.1810 - dist_relevant_mse: 3.1441 - dist_dist_iou_metric: 0.6539 - val_loss: 0.2336 - val_prob_loss: 0.0151 - val_dist_loss: 1.0930 - val_prob_kld: 0.0119 - val_dist_relevant_mae: 1.0926 - val_dist_relevant_mse: 2.4275 - val_dist_dist_iou_metric: 0.6749 - lr: 3.0000e-04
# Epoch 48/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2557 - prob_loss: 0.0151 - dist_loss: 1.2031 - prob_kld: 0.0117 - dist_relevant_mae: 1.2028 - dist_relevant_mse: 3.2678 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2557 - prob_loss: 0.0151 - dist_loss: 1.2031 - prob_kld: 0.0117 - dist_relevant_mae: 1.2028 - dist_relevant_mse: 3.2678 - dist_dist_iou_metric: 0.6516 - val_loss: 0.2392 - val_prob_loss: 0.0144 - val_dist_loss: 1.1239 - val_prob_kld: 0.0112 - val_dist_relevant_mae: 1.1235 - val_dist_relevant_mse: 2.6061 - val_dist_dist_iou_metric: 0.6723 - lr: 3.0000e-04
# Epoch 49/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2517 - prob_loss: 0.0157 - dist_loss: 1.1798 - prob_kld: 0.0123 - dist_relevant_mae: 1.1794 - dist_relevant_mse: 3.0448 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2512 - prob_loss: 0.0157 - dist_loss: 1.1771 - prob_kld: 0.0123 - dist_relevant_mae: 1.1768 - dist_relevant_mse: 3.0296 - dist_dist_iou_metric: 0.6564 - val_loss: 0.2304 - val_prob_loss: 0.0134 - val_dist_loss: 1.0849 - val_prob_kld: 0.0102 - val_dist_relevant_mae: 1.0846 - val_dist_relevant_mse: 2.4010 - val_dist_dist_iou_metric: 0.6630 - lr: 3.0000e-04
# Epoch 50/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2543 - prob_loss: 0.0156 - dist_loss: 1.1936 - prob_kld: 0.0122 - dist_relevant_mae: 1.1932 - dist_relevant_mse: 3.2589 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 4s 42ms/step - loss: 0.2544 - prob_loss: 0.0155 - dist_loss: 1.1944 - prob_kld: 0.0122 - dist_relevant_mae: 1.1940 - dist_relevant_mse: 3.2617 - dist_dist_iou_metric: 0.6522 - val_loss: 0.2409 - val_prob_loss: 0.0155 - val_dist_loss: 1.1274 - val_prob_kld: 0.0123 - val_dist_relevant_mae: 1.1271 - val_dist_relevant_mse: 2.5473 - val_dist_dist_iou_metric: 0.6497 - lr: 3.0000e-04
# Epoch 51/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2511 - prob_loss: 0.0150 - dist_loss: 1.1804 - prob_kld: 0.0119 - dist_relevant_mae: 1.1801 - dist_relevant_mse: 3.0762 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2514 - prob_loss: 0.0150 - dist_loss: 1.1819 - prob_kld: 0.0118 - dist_relevant_mae: 1.1815 - dist_relevant_mse: 3.0815 - dist_dist_iou_metric: 0.6569 - val_loss: 0.2276 - val_prob_loss: 0.0137 - val_dist_loss: 1.0693 - val_prob_kld: 0.0106 - val_dist_relevant_mae: 1.0690 - val_dist_relevant_mse: 2.3788 - val_dist_dist_iou_metric: 0.6692 - lr: 3.0000e-04
# Epoch 52/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2558 - prob_loss: 0.0151 - dist_loss: 1.2035 - prob_kld: 0.0118 - dist_relevant_mae: 1.2031 - dist_relevant_mse: 3.2975 - dist_dist_iou_metric: 0.64
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2560 - prob_loss: 0.0151 - dist_loss: 1.2045 - prob_kld: 0.0118 - dist_relevant_mae: 1.2042 - dist_relevant_mse: 3.2962 - dist_dist_iou_metric: 0.6481 - val_loss: 0.2402 - val_prob_loss: 0.0135 - val_dist_loss: 1.1335 - val_prob_kld: 0.0103 - val_dist_relevant_mae: 1.1331 - val_dist_relevant_mse: 2.6744 - val_dist_dist_iou_metric: 0.6777 - lr: 3.0000e-04
# Epoch 53/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2483 - prob_loss: 0.0148 - dist_loss: 1.1673 - prob_kld: 0.0116 - dist_relevant_mae: 1.1670 - dist_relevant_mse: 2.9694 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2479 - prob_loss: 0.0147 - dist_loss: 1.1656 - prob_kld: 0.0115 - dist_relevant_mae: 1.1653 - dist_relevant_mse: 2.9569 - dist_dist_iou_metric: 0.6603 - val_loss: 0.2327 - val_prob_loss: 0.0142 - val_dist_loss: 1.0924 - val_prob_kld: 0.0110 - val_dist_relevant_mae: 1.0921 - val_dist_relevant_mse: 2.4373 - val_dist_dist_iou_metric: 0.6678 - lr: 3.0000e-04
# Epoch 54/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2444 - prob_loss: 0.0152 - dist_loss: 1.1459 - prob_kld: 0.0119 - dist_relevant_mae: 1.1455 - dist_relevant_mse: 2.9891 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 5s 46ms/step - loss: 0.2441 - prob_loss: 0.0151 - dist_loss: 1.1450 - prob_kld: 0.0118 - dist_relevant_mae: 1.1447 - dist_relevant_mse: 2.9838 - dist_dist_iou_metric: 0.6625 - val_loss: 0.2281 - val_prob_loss: 0.0135 - val_dist_loss: 1.0731 - val_prob_kld: 0.0103 - val_dist_relevant_mae: 1.0727 - val_dist_relevant_mse: 2.3717 - val_dist_dist_iou_metric: 0.6706 - lr: 3.0000e-04
# Epoch 55/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2494 - prob_loss: 0.0143 - dist_loss: 1.1757 - prob_kld: 0.0111 - dist_relevant_mae: 1.1753 - dist_relevant_mse: 3.1118 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 4s 45ms/step - loss: 0.2487 - prob_loss: 0.0142 - dist_loss: 1.1724 - prob_kld: 0.0110 - dist_relevant_mae: 1.1721 - dist_relevant_mse: 3.0925 - dist_dist_iou_metric: 0.6558 - val_loss: 0.2277 - val_prob_loss: 0.0135 - val_dist_loss: 1.0713 - val_prob_kld: 0.0103 - val_dist_relevant_mae: 1.0710 - val_dist_relevant_mse: 2.3744 - val_dist_dist_iou_metric: 0.6789 - lr: 3.0000e-04
# Epoch 56/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2485 - prob_loss: 0.0154 - dist_loss: 1.1655 - prob_kld: 0.0121 - dist_relevant_mae: 1.1652 - dist_relevant_mse: 3.0685 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2482 - prob_loss: 0.0155 - dist_loss: 1.1635 - prob_kld: 0.0121 - dist_relevant_mae: 1.1632 - dist_relevant_mse: 3.0570 - dist_dist_iou_metric: 0.6595 - val_loss: 0.2315 - val_prob_loss: 0.0145 - val_dist_loss: 1.0851 - val_prob_kld: 0.0113 - val_dist_relevant_mae: 1.0847 - val_dist_relevant_mse: 2.4200 - val_dist_dist_iou_metric: 0.6729 - lr: 3.0000e-04
# Epoch 57/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2366 - prob_loss: 0.0138 - dist_loss: 1.1143 - prob_kld: 0.0107 - dist_relevant_mae: 1.1140 - dist_relevant_mse: 2.7984 - dist_dist_iou_metric: 0.67
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2366 - prob_loss: 0.0138 - dist_loss: 1.1142 - prob_kld: 0.0107 - dist_relevant_mae: 1.1138 - dist_relevant_mse: 2.7926 - dist_dist_iou_metric: 0.6713 - val_loss: 0.2348 - val_prob_loss: 0.0132 - val_dist_loss: 1.1082 - val_prob_kld: 0.0100 - val_dist_relevant_mae: 1.1078 - val_dist_relevant_mse: 2.4314 - val_dist_dist_iou_metric: 0.6505 - lr: 3.0000e-04
# Epoch 58/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2483 - prob_loss: 0.0146 - dist_loss: 1.1689 - prob_kld: 0.0114 - dist_relevant_mae: 1.1685 - dist_relevant_mse: 3.0180 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 4s 45ms/step - loss: 0.2477 - prob_loss: 0.0145 - dist_loss: 1.1661 - prob_kld: 0.0113 - dist_relevant_mae: 1.1658 - dist_relevant_mse: 3.0031 - dist_dist_iou_metric: 0.6593 - val_loss: 0.2233 - val_prob_loss: 0.0129 - val_dist_loss: 1.0520 - val_prob_kld: 0.0097 - val_dist_relevant_mae: 1.0517 - val_dist_relevant_mse: 2.2607 - val_dist_dist_iou_metric: 0.6760 - lr: 3.0000e-04
# Epoch 59/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2483 - prob_loss: 0.0154 - dist_loss: 1.1642 - prob_kld: 0.0118 - dist_relevant_mae: 1.1639 - dist_relevant_mse: 3.1442 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2483 - prob_loss: 0.0154 - dist_loss: 1.1642 - prob_kld: 0.0118 - dist_relevant_mae: 1.1639 - dist_relevant_mse: 3.1442 - dist_dist_iou_metric: 0.6609 - val_loss: 0.2245 - val_prob_loss: 0.0135 - val_dist_loss: 1.0551 - val_prob_kld: 0.0103 - val_dist_relevant_mae: 1.0548 - val_dist_relevant_mse: 2.2993 - val_dist_dist_iou_metric: 0.6731 - lr: 3.0000e-04
# Epoch 60/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2435 - prob_loss: 0.0145 - dist_loss: 1.1447 - prob_kld: 0.0113 - dist_relevant_mae: 1.1444 - dist_relevant_mse: 2.9391 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2432 - prob_loss: 0.0145 - dist_loss: 1.1435 - prob_kld: 0.0112 - dist_relevant_mae: 1.1431 - dist_relevant_mse: 2.9310 - dist_dist_iou_metric: 0.6677 - val_loss: 0.2232 - val_prob_loss: 0.0132 - val_dist_loss: 1.0499 - val_prob_kld: 0.0100 - val_dist_relevant_mae: 1.0496 - val_dist_relevant_mse: 2.2813 - val_dist_dist_iou_metric: 0.6781 - lr: 3.0000e-04
# Epoch 61/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2388 - prob_loss: 0.0144 - dist_loss: 1.1224 - prob_kld: 0.0112 - dist_relevant_mae: 1.1221 - dist_relevant_mse: 2.8787 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2387 - prob_loss: 0.0144 - dist_loss: 1.1216 - prob_kld: 0.0112 - dist_relevant_mae: 1.1213 - dist_relevant_mse: 2.8701 - dist_dist_iou_metric: 0.6696 - val_loss: 0.2341 - val_prob_loss: 0.0146 - val_dist_loss: 1.0971 - val_prob_kld: 0.0115 - val_dist_relevant_mae: 1.0968 - val_dist_relevant_mse: 2.4476 - val_dist_dist_iou_metric: 0.6570 - lr: 3.0000e-04
# Epoch 62/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2436 - prob_loss: 0.0146 - dist_loss: 1.1452 - prob_kld: 0.0113 - dist_relevant_mae: 1.1448 - dist_relevant_mse: 2.9628 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2436 - prob_loss: 0.0146 - dist_loss: 1.1452 - prob_kld: 0.0113 - dist_relevant_mae: 1.1448 - dist_relevant_mse: 2.9580 - dist_dist_iou_metric: 0.6624 - val_loss: 0.2264 - val_prob_loss: 0.0131 - val_dist_loss: 1.0665 - val_prob_kld: 0.0099 - val_dist_relevant_mae: 1.0662 - val_dist_relevant_mse: 2.3409 - val_dist_dist_iou_metric: 0.6747 - lr: 3.0000e-04
# Epoch 63/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2425 - prob_loss: 0.0137 - dist_loss: 1.1440 - prob_kld: 0.0107 - dist_relevant_mae: 1.1436 - dist_relevant_mse: 2.8737 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2423 - prob_loss: 0.0138 - dist_loss: 1.1423 - prob_kld: 0.0108 - dist_relevant_mae: 1.1420 - dist_relevant_mse: 2.8633 - dist_dist_iou_metric: 0.6594 - val_loss: 0.2323 - val_prob_loss: 0.0138 - val_dist_loss: 1.0927 - val_prob_kld: 0.0106 - val_dist_relevant_mae: 1.0923 - val_dist_relevant_mse: 2.4076 - val_dist_dist_iou_metric: 0.6840 - lr: 3.0000e-04
# Epoch 64/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2461 - prob_loss: 0.0148 - dist_loss: 1.1565 - prob_kld: 0.0115 - dist_relevant_mae: 1.1562 - dist_relevant_mse: 2.9808 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 4s 42ms/step - loss: 0.2459 - prob_loss: 0.0148 - dist_loss: 1.1555 - prob_kld: 0.0115 - dist_relevant_mae: 1.1552 - dist_relevant_mse: 2.9725 - dist_dist_iou_metric: 0.6629 - val_loss: 0.2316 - val_prob_loss: 0.0130 - val_dist_loss: 1.0933 - val_prob_kld: 0.0098 - val_dist_relevant_mae: 1.0930 - val_dist_relevant_mse: 2.4605 - val_dist_dist_iou_metric: 0.6647 - lr: 3.0000e-04
# Epoch 65/400
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2430 - prob_loss: 0.0146 - dist_loss: 1.1420 - prob_kld: 0.0112 - dist_relevant_mae: 1.1416 - dist_relevant_mse: 2.9953 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2427 - prob_loss: 0.0146 - dist_loss: 1.1406 - prob_kld: 0.0112 - dist_relevant_mae: 1.1403 - dist_relevant_mse: 2.9872 - dist_dist_iou_metric: 0.6680 - val_loss: 0.2261 - val_prob_loss: 0.0135 - val_dist_loss: 1.0629 - val_prob_kld: 0.0104 - val_dist_relevant_mae: 1.0626 - val_dist_relevant_mse: 2.3631 - val_dist_dist_iou_metric: 0.6909 - lr: 3.0000e-04
# Epoch 66/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2385 - prob_loss: 0.0141 - dist_loss: 1.1217 - prob_kld: 0.0109 - dist_relevant_mae: 1.1214 - dist_relevant_mse: 2.8904 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2387 - prob_loss: 0.0140 - dist_loss: 1.1234 - prob_kld: 0.0109 - dist_relevant_mae: 1.1231 - dist_relevant_mse: 2.8983 - dist_dist_iou_metric: 0.6687 - val_loss: 0.2244 - val_prob_loss: 0.0129 - val_dist_loss: 1.0578 - val_prob_kld: 0.0097 - val_dist_relevant_mae: 1.0575 - val_dist_relevant_mse: 2.3157 - val_dist_dist_iou_metric: 0.6886 - lr: 3.0000e-04
# Epoch 67/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2422 - prob_loss: 0.0138 - dist_loss: 1.1422 - prob_kld: 0.0105 - dist_relevant_mae: 1.1419 - dist_relevant_mse: 2.9795 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2430 - prob_loss: 0.0141 - dist_loss: 1.1445 - prob_kld: 0.0108 - dist_relevant_mae: 1.1441 - dist_relevant_mse: 2.9951 - dist_dist_iou_metric: 0.6655 - val_loss: 0.2267 - val_prob_loss: 0.0124 - val_dist_loss: 1.0713 - val_prob_kld: 0.0092 - val_dist_relevant_mae: 1.0709 - val_dist_relevant_mse: 2.4153 - val_dist_dist_iou_metric: 0.6889 - lr: 3.0000e-04
# Epoch 68/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2343 - prob_loss: 0.0135 - dist_loss: 1.1037 - prob_kld: 0.0104 - dist_relevant_mae: 1.1034 - dist_relevant_mse: 2.6517 - dist_dist_iou_metric: 0.67
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2343 - prob_loss: 0.0135 - dist_loss: 1.1037 - prob_kld: 0.0104 - dist_relevant_mae: 1.1034 - dist_relevant_mse: 2.6517 - dist_dist_iou_metric: 0.6700 - val_loss: 0.2249 - val_prob_loss: 0.0136 - val_dist_loss: 1.0565 - val_prob_kld: 0.0104 - val_dist_relevant_mae: 1.0562 - val_dist_relevant_mse: 2.2694 - val_dist_dist_iou_metric: 0.6755 - lr: 3.0000e-04
# Epoch 69/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2403 - prob_loss: 0.0139 - dist_loss: 1.1320 - prob_kld: 0.0107 - dist_relevant_mae: 1.1317 - dist_relevant_mse: 2.8951 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2397 - prob_loss: 0.0138 - dist_loss: 1.1295 - prob_kld: 0.0106 - dist_relevant_mae: 1.1292 - dist_relevant_mse: 2.8796 - dist_dist_iou_metric: 0.6688 - val_loss: 0.2175 - val_prob_loss: 0.0126 - val_dist_loss: 1.0245 - val_prob_kld: 0.0094 - val_dist_relevant_mae: 1.0242 - val_dist_relevant_mse: 2.2277 - val_dist_dist_iou_metric: 0.6896 - lr: 3.0000e-04
# Epoch 70/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2416 - prob_loss: 0.0144 - dist_loss: 1.1360 - prob_kld: 0.0110 - dist_relevant_mae: 1.1357 - dist_relevant_mse: 2.9994 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2420 - prob_loss: 0.0144 - dist_loss: 1.1381 - prob_kld: 0.0111 - dist_relevant_mae: 1.1377 - dist_relevant_mse: 3.0114 - dist_dist_iou_metric: 0.6683 - val_loss: 0.2153 - val_prob_loss: 0.0126 - val_dist_loss: 1.0133 - val_prob_kld: 0.0095 - val_dist_relevant_mae: 1.0130 - val_dist_relevant_mse: 2.1640 - val_dist_dist_iou_metric: 0.6919 - lr: 3.0000e-04
# Epoch 71/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2403 - prob_loss: 0.0143 - dist_loss: 1.1300 - prob_kld: 0.0109 - dist_relevant_mae: 1.1296 - dist_relevant_mse: 2.9675 - dist_dist_iou_metric: 0.67
# ...
# Epoch 377/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1422 - prob_loss: 0.0105 - dist_loss: 0.6585 - prob_kld: 0.0071 - dist_relevant_mae: 0.6583 - dist_relevant_mse: 0.9071 - dist_dist_iou_metric: 0.78
# 100/100 [==============================] - 5s 46ms/step - loss: 0.1422 - prob_loss: 0.0105 - dist_loss: 0.6585 - prob_kld: 0.0071 - dist_relevant_mae: 0.6582 - dist_relevant_mse: 0.9066 - dist_dist_iou_metric: 0.7850 - val_loss: 0.2192 - val_prob_loss: 0.0109 - val_dist_loss: 1.0415 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.0413 - val_dist_relevant_mse: 2.5278 - val_dist_dist_iou_metric: 0.6874 - lr: 9.3750e-06
# Epoch 378/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1375 - prob_loss: 0.0095 - dist_loss: 0.6399 - prob_kld: 0.0064 - dist_relevant_mae: 0.6397 - dist_relevant_mse: 0.8547 - dist_dist_iou_metric: 0.79
# 100/100 [==============================] - 4s 42ms/step - loss: 0.1373 - prob_loss: 0.0095 - dist_loss: 0.6393 - prob_kld: 0.0064 - dist_relevant_mae: 0.6390 - dist_relevant_mse: 0.8529 - dist_dist_iou_metric: 0.7946 - val_loss: 0.2192 - val_prob_loss: 0.0109 - val_dist_loss: 1.0418 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.0416 - val_dist_relevant_mse: 2.5246 - val_dist_dist_iou_metric: 0.6884 - lr: 9.3750e-06
# Epoch 379/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1446 - prob_loss: 0.0110 - dist_loss: 0.6679 - prob_kld: 0.0075 - dist_relevant_mae: 0.6677 - dist_relevant_mse: 0.9648 - dist_dist_iou_metric: 0.78
# 100/100 [==============================] - 4s 44ms/step - loss: 0.1446 - prob_loss: 0.0110 - dist_loss: 0.6679 - prob_kld: 0.0075 - dist_relevant_mae: 0.6677 - dist_relevant_mse: 0.9648 - dist_dist_iou_metric: 0.7845 - val_loss: 0.2192 - val_prob_loss: 0.0109 - val_dist_loss: 1.0414 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.0412 - val_dist_relevant_mse: 2.5297 - val_dist_dist_iou_metric: 0.6884 - lr: 9.3750e-06
# Epoch 380/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1385 - prob_loss: 0.0097 - dist_loss: 0.6440 - prob_kld: 0.0066 - dist_relevant_mae: 0.6438 - dist_relevant_mse: 0.8795 - dist_dist_iou_metric: 0.79
# 100/100 [==============================] - 4s 42ms/step - loss: 0.1391 - prob_loss: 0.0099 - dist_loss: 0.6462 - prob_kld: 0.0066 - dist_relevant_mae: 0.6460 - dist_relevant_mse: 0.8881 - dist_dist_iou_metric: 0.7925 - val_loss: 0.2196 - val_prob_loss: 0.0109 - val_dist_loss: 1.0436 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.0434 - val_dist_relevant_mse: 2.5375 - val_dist_dist_iou_metric: 0.6872 - lr: 9.3750e-06
# Epoch 381/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1413 - prob_loss: 0.0103 - dist_loss: 0.6550 - prob_kld: 0.0070 - dist_relevant_mae: 0.6547 - dist_relevant_mse: 0.8865 - dist_dist_iou_metric: 0.78
# 100/100 [==============================] - 4s 42ms/step - loss: 0.1415 - prob_loss: 0.0105 - dist_loss: 0.6550 - prob_kld: 0.0071 - dist_relevant_mae: 0.6548 - dist_relevant_mse: 0.8868 - dist_dist_iou_metric: 0.7883 - val_loss: 0.2200 - val_prob_loss: 0.0109 - val_dist_loss: 1.0453 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.0450 - val_dist_relevant_mse: 2.5437 - val_dist_dist_iou_metric: 0.6873 - lr: 9.3750e-06
# Epoch 382/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1347 - prob_loss: 0.0090 - dist_loss: 0.6286 - prob_kld: 0.0062 - dist_relevant_mae: 0.6284 - dist_relevant_mse: 0.7989 - dist_dist_iou_metric: 0.79
# 100/100 [==============================] - 4s 42ms/step - loss: 0.1349 - prob_loss: 0.0091 - dist_loss: 0.6292 - prob_kld: 0.0063 - dist_relevant_mae: 0.6289 - dist_relevant_mse: 0.8002 - dist_dist_iou_metric: 0.7935 - val_loss: 0.2206 - val_prob_loss: 0.0110 - val_dist_loss: 1.0482 - val_prob_kld: 0.0078 - val_dist_relevant_mae: 1.0479 - val_dist_relevant_mse: 2.5535 - val_dist_dist_iou_metric: 0.6860 - lr: 9.3750e-06
# Epoch 383/400
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1447 - prob_loss: 0.0110 - dist_loss: 0.6684 - prob_kld: 0.0074 - dist_relevant_mae: 0.6681 - dist_relevant_mse: 0.9567 - dist_dist_iou_metric: 0.78
# 100/100 [==============================] - 4s 42ms/step - loss: 0.1446 - prob_loss: 0.0110 - dist_loss: 0.6681 - prob_kld: 0.0074 - dist_relevant_mae: 0.6678 - dist_relevant_mse: 0.9558 - dist_dist_iou_metric: 0.7845 - val_loss: 0.2195 - val_prob_loss: 0.0109 - val_dist_loss: 1.0430 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.0428 - val_dist_relevant_mse: 2.5376 - val_dist_dist_iou_metric: 0.6865 - lr: 9.3750e-06
# Epoch 384/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1368 - prob_loss: 0.0092 - dist_loss: 0.6378 - prob_kld: 0.0063 - dist_relevant_mae: 0.6376 - dist_relevant_mse: 0.8422 - dist_dist_iou_metric: 0.79
# 100/100 [==============================] - 4s 43ms/step - loss: 0.1369 - prob_loss: 0.0093 - dist_loss: 0.6382 - prob_kld: 0.0063 - dist_relevant_mae: 0.6380 - dist_relevant_mse: 0.8427 - dist_dist_iou_metric: 0.7950 - val_loss: 0.2195 - val_prob_loss: 0.0110 - val_dist_loss: 1.0429 - val_prob_kld: 0.0078 - val_dist_relevant_mae: 1.0427 - val_dist_relevant_mse: 2.5360 - val_dist_dist_iou_metric: 0.6870 - lr: 9.3750e-06
# Epoch 385/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1404 - prob_loss: 0.0101 - dist_loss: 0.6514 - prob_kld: 0.0068 - dist_relevant_mae: 0.6512 - dist_relevant_mse: 0.8769 - dist_dist_iou_metric: 0.79
# 100/100 [==============================] - 4s 45ms/step - loss: 0.1407 - prob_loss: 0.0103 - dist_loss: 0.6522 - prob_kld: 0.0069 - dist_relevant_mae: 0.6520 - dist_relevant_mse: 0.8787 - dist_dist_iou_metric: 0.7902 - val_loss: 0.2189 - val_prob_loss: 0.0109 - val_dist_loss: 1.0397 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.0395 - val_dist_relevant_mse: 2.5223 - val_dist_dist_iou_metric: 0.6877 - lr: 9.3750e-06
# Epoch 386/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1428 - prob_loss: 0.0107 - dist_loss: 0.6607 - prob_kld: 0.0072 - dist_relevant_mae: 0.6604 - dist_relevant_mse: 0.9512 - dist_dist_iou_metric: 0.78
# 100/100 [==============================] - 4s 43ms/step - loss: 0.1425 - prob_loss: 0.0107 - dist_loss: 0.6594 - prob_kld: 0.0072 - dist_relevant_mae: 0.6592 - dist_relevant_mse: 0.9475 - dist_dist_iou_metric: 0.7880 - val_loss: 0.2198 - val_prob_loss: 0.0109 - val_dist_loss: 1.0445 - val_prob_kld: 0.0078 - val_dist_relevant_mae: 1.0443 - val_dist_relevant_mse: 2.5456 - val_dist_dist_iou_metric: 0.6859 - lr: 9.3750e-06
# Epoch 387/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1401 - prob_loss: 0.0097 - dist_loss: 0.6521 - prob_kld: 0.0066 - dist_relevant_mae: 0.6518 - dist_relevant_mse: 0.8950 - dist_dist_iou_metric: 0.78
# 100/100 [==============================] - 4s 44ms/step - loss: 0.1401 - prob_loss: 0.0097 - dist_loss: 0.6521 - prob_kld: 0.0066 - dist_relevant_mae: 0.6518 - dist_relevant_mse: 0.8950 - dist_dist_iou_metric: 0.7874 - val_loss: 0.2201 - val_prob_loss: 0.0110 - val_dist_loss: 1.0456 - val_prob_kld: 0.0078 - val_dist_relevant_mae: 1.0453 - val_dist_relevant_mse: 2.5453 - val_dist_dist_iou_metric: 0.6849 - lr: 9.3750e-06
# Epoch 388/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1385 - prob_loss: 0.0101 - dist_loss: 0.6419 - prob_kld: 0.0068 - dist_relevant_mae: 0.6416 - dist_relevant_mse: 0.8701 - dist_dist_iou_metric: 0.79
# 100/100 [==============================] - 4s 41ms/step - loss: 0.1384 - prob_loss: 0.0101 - dist_loss: 0.6414 - prob_kld: 0.0068 - dist_relevant_mae: 0.6412 - dist_relevant_mse: 0.8688 - dist_dist_iou_metric: 0.7910 - val_loss: 0.2203 - val_prob_loss: 0.0109 - val_dist_loss: 1.0467 - val_prob_kld: 0.0078 - val_dist_relevant_mae: 1.0465 - val_dist_relevant_mse: 2.5585 - val_dist_dist_iou_metric: 0.6851 - lr: 9.3750e-06
# Epoch 389/400
#  99/100 [============================>.] - ETA: 0s - loss: 0.1420 - prob_loss: 0.0104 - dist_loss: 0.6580 - prob_kld: 0.0070 - dist_relevant_mae: 0.6578 - dist_relevant_mse: 0.9058 - dist_dist_iou_metric: 0.7882
# Epoch 389: ReduceLROnPlateau reducing learning rate to 4.687500222644303e-06.
# 3/3 [==============================] - 0s 3ms/step
# 100/100 [==============================] - 4s 42ms/step - loss: 0.1419 - prob_loss: 0.0103 - dist_loss: 0.6579 - prob_kld: 0.0070 - dist_relevant_mae: 0.6577 - dist_relevant_mse: 0.9053 - dist_dist_iou_metric: 0.7879 - val_loss: 0.2198 - val_prob_loss: 0.0109 - val_dist_loss: 1.0442 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.0440 - val_dist_relevant_mse: 2.5414 - val_dist_dist_iou_metric: 0.6872 - lr: 9.3750e-06
# Epoch 390/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1414 - prob_loss: 0.0107 - dist_loss: 0.6535 - prob_kld: 0.0073 - dist_relevant_mae: 0.6533 - dist_relevant_mse: 0.9137 - dist_dist_iou_metric: 0.79
# 100/100 [==============================] - 4s 42ms/step - loss: 0.1415 - prob_loss: 0.0107 - dist_loss: 0.6537 - prob_kld: 0.0073 - dist_relevant_mae: 0.6535 - dist_relevant_mse: 0.9154 - dist_dist_iou_metric: 0.7901 - val_loss: 0.2201 - val_prob_loss: 0.0109 - val_dist_loss: 1.0460 - val_prob_kld: 0.0078 - val_dist_relevant_mae: 1.0457 - val_dist_relevant_mse: 2.5486 - val_dist_dist_iou_metric: 0.6859 - lr: 4.6875e-06
# Epoch 391/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1346 - prob_loss: 0.0091 - dist_loss: 0.6275 - prob_kld: 0.0061 - dist_relevant_mae: 0.6273 - dist_relevant_mse: 0.8063 - dist_dist_iou_metric: 0.79
# 100/100 [==============================] - 4s 42ms/step - loss: 0.1346 - prob_loss: 0.0091 - dist_loss: 0.6275 - prob_kld: 0.0061 - dist_relevant_mae: 0.6273 - dist_relevant_mse: 0.8063 - dist_dist_iou_metric: 0.7962 - val_loss: 0.2201 - val_prob_loss: 0.0110 - val_dist_loss: 1.0458 - val_prob_kld: 0.0078 - val_dist_relevant_mae: 1.0456 - val_dist_relevant_mse: 2.5575 - val_dist_dist_iou_metric: 0.6860 - lr: 4.6875e-06
# Epoch 392/400
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1413 - prob_loss: 0.0101 - dist_loss: 0.6560 - prob_kld: 0.0069 - dist_relevant_mae: 0.6558 - dist_relevant_mse: 0.9074 - dist_dist_iou_metric: 0.78
# 100/100 [==============================] - 4s 42ms/step - loss: 0.1414 - prob_loss: 0.0101 - dist_loss: 0.6568 - prob_kld: 0.0068 - dist_relevant_mae: 0.6566 - dist_relevant_mse: 0.9114 - dist_dist_iou_metric: 0.7886 - val_loss: 0.2198 - val_prob_loss: 0.0110 - val_dist_loss: 1.0443 - val_prob_kld: 0.0078 - val_dist_relevant_mae: 1.0441 - val_dist_relevant_mse: 2.5450 - val_dist_dist_iou_metric: 0.6860 - lr: 4.6875e-06
# Epoch 393/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1388 - prob_loss: 0.0095 - dist_loss: 0.6467 - prob_kld: 0.0065 - dist_relevant_mae: 0.6465 - dist_relevant_mse: 0.8807 - dist_dist_iou_metric: 0.78
# 100/100 [==============================] - 4s 41ms/step - loss: 0.1388 - prob_loss: 0.0095 - dist_loss: 0.6467 - prob_kld: 0.0065 - dist_relevant_mae: 0.6465 - dist_relevant_mse: 0.8807 - dist_dist_iou_metric: 0.7862 - val_loss: 0.2198 - val_prob_loss: 0.0110 - val_dist_loss: 1.0443 - val_prob_kld: 0.0078 - val_dist_relevant_mae: 1.0441 - val_dist_relevant_mse: 2.5553 - val_dist_dist_iou_metric: 0.6870 - lr: 4.6875e-06
# Epoch 394/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1413 - prob_loss: 0.0108 - dist_loss: 0.6524 - prob_kld: 0.0072 - dist_relevant_mae: 0.6521 - dist_relevant_mse: 0.8826 - dist_dist_iou_metric: 0.79
# 100/100 [==============================] - 4s 42ms/step - loss: 0.1413 - prob_loss: 0.0108 - dist_loss: 0.6523 - prob_kld: 0.0072 - dist_relevant_mae: 0.6520 - dist_relevant_mse: 0.8814 - dist_dist_iou_metric: 0.7902 - val_loss: 0.2200 - val_prob_loss: 0.0109 - val_dist_loss: 1.0456 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.0454 - val_dist_relevant_mse: 2.5510 - val_dist_dist_iou_metric: 0.6863 - lr: 4.6875e-06
# Epoch 395/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1399 - prob_loss: 0.0100 - dist_loss: 0.6496 - prob_kld: 0.0067 - dist_relevant_mae: 0.6494 - dist_relevant_mse: 0.8772 - dist_dist_iou_metric: 0.79
# 100/100 [==============================] - 4s 43ms/step - loss: 0.1405 - prob_loss: 0.0100 - dist_loss: 0.6530 - prob_kld: 0.0067 - dist_relevant_mae: 0.6527 - dist_relevant_mse: 0.8896 - dist_dist_iou_metric: 0.7920 - val_loss: 0.2200 - val_prob_loss: 0.0109 - val_dist_loss: 1.0452 - val_prob_kld: 0.0078 - val_dist_relevant_mae: 1.0450 - val_dist_relevant_mse: 2.5482 - val_dist_dist_iou_metric: 0.6860 - lr: 4.6875e-06
# Epoch 396/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1382 - prob_loss: 0.0099 - dist_loss: 0.6417 - prob_kld: 0.0068 - dist_relevant_mae: 0.6415 - dist_relevant_mse: 0.8748 - dist_dist_iou_metric: 0.78
# 100/100 [==============================] - 5s 46ms/step - loss: 0.1382 - prob_loss: 0.0099 - dist_loss: 0.6415 - prob_kld: 0.0068 - dist_relevant_mae: 0.6413 - dist_relevant_mse: 0.8737 - dist_dist_iou_metric: 0.7884 - val_loss: 0.2195 - val_prob_loss: 0.0109 - val_dist_loss: 1.0431 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.0429 - val_dist_relevant_mse: 2.5406 - val_dist_dist_iou_metric: 0.6874 - lr: 4.6875e-06
# Epoch 397/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1408 - prob_loss: 0.0104 - dist_loss: 0.6523 - prob_kld: 0.0070 - dist_relevant_mae: 0.6520 - dist_relevant_mse: 0.8927 - dist_dist_iou_metric: 0.79
# 100/100 [==============================] - 4s 41ms/step - loss: 0.1406 - prob_loss: 0.0104 - dist_loss: 0.6510 - prob_kld: 0.0069 - dist_relevant_mae: 0.6508 - dist_relevant_mse: 0.8890 - dist_dist_iou_metric: 0.7906 - val_loss: 0.2197 - val_prob_loss: 0.0109 - val_dist_loss: 1.0443 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.0440 - val_dist_relevant_mse: 2.5456 - val_dist_dist_iou_metric: 0.6871 - lr: 4.6875e-06
# Epoch 398/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1373 - prob_loss: 0.0095 - dist_loss: 0.6394 - prob_kld: 0.0065 - dist_relevant_mae: 0.6392 - dist_relevant_mse: 0.8514 - dist_dist_iou_metric: 0.79
# 100/100 [==============================] - 4s 41ms/step - loss: 0.1374 - prob_loss: 0.0095 - dist_loss: 0.6395 - prob_kld: 0.0065 - dist_relevant_mae: 0.6393 - dist_relevant_mse: 0.8520 - dist_dist_iou_metric: 0.7925 - val_loss: 0.2199 - val_prob_loss: 0.0110 - val_dist_loss: 1.0448 - val_prob_kld: 0.0078 - val_dist_relevant_mae: 1.0446 - val_dist_relevant_mse: 2.5543 - val_dist_dist_iou_metric: 0.6861 - lr: 4.6875e-06
# Epoch 399/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1391 - prob_loss: 0.0102 - dist_loss: 0.6448 - prob_kld: 0.0069 - dist_relevant_mae: 0.6446 - dist_relevant_mse: 0.8763 - dist_dist_iou_metric: 0.79
# 100/100 [==============================] - 4s 42ms/step - loss: 0.1390 - prob_loss: 0.0102 - dist_loss: 0.6441 - prob_kld: 0.0069 - dist_relevant_mae: 0.6439 - dist_relevant_mse: 0.8745 - dist_dist_iou_metric: 0.7920 - val_loss: 0.2200 - val_prob_loss: 0.0109 - val_dist_loss: 1.0455 - val_prob_kld: 0.0078 - val_dist_relevant_mae: 1.0453 - val_dist_relevant_mse: 2.5558 - val_dist_dist_iou_metric: 0.6865 - lr: 4.6875e-06
# Epoch 400/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1408 - prob_loss: 0.0109 - dist_loss: 0.6496 - prob_kld: 0.0072 - dist_relevant_mae: 0.6494 - dist_relevant_mse: 0.8929 - dist_dist_iou_metric: 0.78
# 100/100 [==============================] - 4s 43ms/step - loss: 0.1406 - prob_loss: 0.0108 - dist_loss: 0.6492 - prob_kld: 0.0072 - dist_relevant_mae: 0.6489 - dist_relevant_mse: 0.8919 - dist_dist_iou_metric: 0.7893 - val_loss: 0.2201 - val_prob_loss: 0.0109 - val_dist_loss: 1.0459 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.0457 - val_dist_relevant_mse: 2.5553 - val_dist_dist_iou_metric: 0.6864 - lr: 4.6875e-06
#
# Loading network weights from 'weights_best.h5'.

# %% [markdown]
# # Threshold optimization

# %% [markdown]
# While the default values for the probability and non-maximum suppression thresholds already yield good results in many cases, we still recommend to adapt the thresholds to your data. The optimized threshold values are saved to disk and will be automatically loaded with the model.

# %%
if quick_demo:
    model.optimize_thresholds(X_val[:2], Y_val[:2])
else:
    model.optimize_thresholds(X_val, Y_val)
# Out:
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# NMS threshold = 0.3:  80%|████████  | 16/20 [00:05<00:01,  2.92it/s, 0.393 -> 0.187]
# NMS threshold = 0.4:  80%|████████  | 16/20 [00:03<00:00,  4.24it/s, 0.393 -> 0.187]
# NMS threshold = 0.5:  80%|████████  | 16/20 [00:03<00:00,  4.59it/s, 0.393 -> 0.187]
# Using optimized values: prob_thresh=0.392095, nms_thresh=0.3.
# Saving to 'thresholds.json'.

# %% [markdown]
# # Evaluation and Detection Performance

# %% [markdown]
# Besides the losses and metrics during training, we can also quantitatively evaluate the actual detection/segmentation performance on the validation data by considering objects in the ground truth to be correctly matched if there are predicted objects with overlap (here [intersection over union (IoU)](https://en.wikipedia.org/wiki/Jaccard_index)) beyond a chosen IoU threshold $\tau$.
#
# The corresponding matching statistics (average overlap, accuracy, recall, precision, etc.) are typically of greater practical relevance than the losses/metrics computed during training (but harder to formulate as a loss function).
# The value of $\tau$ can be between 0 (even slightly overlapping objects count as correctly predicted) and 1 (only pixel-perfectly overlapping objects count) and which $\tau$ to use depends on the needed segmentation precision/application.
#
# Please see `help(matching)` for definitions of the abbreviations used in the evaluation below and see the Wikipedia page on [Sensitivity and specificity](https://en.wikipedia.org/wiki/Sensitivity_and_specificity) for further details.

# %%
# help(matching)

# %% [markdown]
# First predict the labels for all validation images:

# %%
Y_val_pred = [model.predict_instances(x, n_tiles=model._guess_n_tiles(x), show_tile_progress=False, prob_thresh=0.2)[0]
              for x in tqdm(X_val)]
# Out:
#   0%|          | 0/174 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
#   1%|          | 2/174 [00:00<00:10, 16.89it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
#   2%|▏         | 4/174 [00:00<00:10, 16.43it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
#   3%|▎         | 6/174 [00:00<00:09, 16.97it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
#   5%|▍         | 8/174 [00:00<00:10, 16.18it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
#   6%|▌         | 10/174 [00:00<00:11, 14.71it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
#   7%|▋         | 12/174 [00:00<00:10, 14.93it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
#   8%|▊         | 14/174 [00:00<00:10, 15.29it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
#   9%|▉         | 16/174 [00:01<00:11, 13.27it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
#  10%|█         | 18/174 [00:01<00:11, 14.12it/s]
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
#  11%|█▏        | 20/174 [00:01<00:10, 14.55it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
#  13%|█▎        | 22/174 [00:01<00:10, 15.18it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
#  14%|█▍        | 24/174 [00:01<00:09, 15.51it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
#  15%|█▍        | 26/174 [00:01<00:09, 15.53it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
#  16%|█▌        | 28/174 [00:01<00:09, 15.80it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
#  17%|█▋        | 30/174 [00:01<00:09, 15.90it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
#  18%|█▊        | 32/174 [00:02<00:08, 16.16it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
#  20%|█▉        | 34/174 [00:02<00:08, 16.31it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
#  21%|██        | 36/174 [00:02<00:08, 16.19it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
#  22%|██▏       | 38/174 [00:02<00:08, 16.24it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
#  23%|██▎       | 40/174 [00:02<00:08, 16.58it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
#  24%|██▍       | 42/174 [00:02<00:08, 16.47it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
#  25%|██▌       | 44/174 [00:02<00:07, 16.38it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
#  26%|██▋       | 46/174 [00:02<00:07, 16.14it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
#  28%|██▊       | 48/174 [00:03<00:07, 15.89it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
#  29%|██▊       | 50/174 [00:03<00:07, 16.13it/s]
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
#  30%|██▉       | 52/174 [00:03<00:07, 16.12it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
#  31%|███       | 54/174 [00:03<00:07, 16.49it/s]
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
#  32%|███▏      | 56/174 [00:03<00:06, 16.95it/s]
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
#  33%|███▎      | 58/174 [00:03<00:06, 16.95it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
#  34%|███▍      | 60/174 [00:03<00:07, 15.97it/s]
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
#  36%|███▌      | 62/174 [00:03<00:07, 15.13it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
#  37%|███▋      | 64/174 [00:04<00:07, 14.27it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
#  38%|███▊      | 66/174 [00:04<00:07, 14.82it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
#  39%|███▉      | 68/174 [00:04<00:06, 15.28it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
#  40%|████      | 70/174 [00:04<00:06, 15.69it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
#  41%|████▏     | 72/174 [00:04<00:07, 14.11it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
#  43%|████▎     | 74/174 [00:04<00:06, 14.58it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
#  44%|████▎     | 76/174 [00:04<00:06, 15.29it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
#  45%|████▍     | 78/174 [00:05<00:06, 15.61it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
#  46%|████▌     | 80/174 [00:05<00:06, 15.49it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
#  47%|████▋     | 82/174 [00:05<00:06, 15.33it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
#  48%|████▊     | 84/174 [00:05<00:06, 13.51it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
#  49%|████▉     | 86/174 [00:05<00:06, 14.25it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
#  51%|█████     | 88/174 [00:05<00:05, 14.51it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
#  52%|█████▏    | 90/174 [00:05<00:05, 14.52it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
#  53%|█████▎    | 92/174 [00:05<00:05, 14.79it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
#  54%|█████▍    | 94/174 [00:06<00:05, 15.32it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
#  55%|█████▌    | 96/174 [00:06<00:04, 15.72it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
#  56%|█████▋    | 98/174 [00:06<00:04, 16.00it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
#  57%|█████▋    | 100/174 [00:06<00:04, 16.21it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
#  59%|█████▊    | 102/174 [00:06<00:04, 16.30it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
#  60%|█████▉    | 104/174 [00:06<00:04, 16.51it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
#  61%|██████    | 106/174 [00:06<00:04, 16.66it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
#  62%|██████▏   | 108/174 [00:06<00:04, 16.19it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
#  63%|██████▎   | 110/174 [00:07<00:03, 16.34it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
#  64%|██████▍   | 112/174 [00:07<00:03, 16.52it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
#  66%|██████▌   | 114/174 [00:07<00:03, 16.97it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
#  67%|██████▋   | 116/174 [00:07<00:03, 16.96it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
#  68%|██████▊   | 118/174 [00:07<00:03, 16.91it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
#  69%|██████▉   | 120/174 [00:07<00:03, 16.86it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
#  70%|███████   | 122/174 [00:07<00:03, 16.94it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
#  71%|███████▏  | 124/174 [00:07<00:02, 17.11it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
#  72%|███████▏  | 126/174 [00:08<00:02, 16.71it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
#  74%|███████▎  | 128/174 [00:08<00:02, 16.81it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
#  75%|███████▍  | 130/174 [00:08<00:02, 16.67it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
#  76%|███████▌  | 132/174 [00:08<00:02, 16.78it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
#  77%|███████▋  | 134/174 [00:08<00:02, 16.65it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
#  78%|███████▊  | 136/174 [00:08<00:02, 16.89it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
#  79%|███████▉  | 138/174 [00:08<00:02, 16.71it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
#  80%|████████  | 140/174 [00:08<00:02, 16.61it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
#  82%|████████▏ | 142/174 [00:08<00:01, 16.69it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
#  83%|████████▎ | 144/174 [00:09<00:01, 16.41it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
#  84%|████████▍ | 146/174 [00:09<00:01, 16.50it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
#  85%|████████▌ | 148/174 [00:09<00:01, 16.57it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
#  86%|████████▌ | 150/174 [00:09<00:01, 16.52it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
#  87%|████████▋ | 152/174 [00:09<00:01, 16.18it/s]
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
#  89%|████████▊ | 154/174 [00:09<00:01, 15.87it/s]
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
#  90%|████████▉ | 156/174 [00:09<00:01, 16.30it/s]
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
#  91%|█████████ | 158/174 [00:09<00:00, 16.26it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
#  92%|█████████▏| 160/174 [00:10<00:00, 16.47it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
#  93%|█████████▎| 162/174 [00:10<00:00, 16.12it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
#  94%|█████████▍| 164/174 [00:10<00:00, 15.59it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
#  95%|█████████▌| 166/174 [00:10<00:00, 14.62it/s]
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
#  97%|█████████▋| 168/174 [00:10<00:00, 15.08it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
#  98%|█████████▊| 170/174 [00:10<00:00, 15.39it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
#  99%|█████████▉| 172/174 [00:10<00:00, 15.77it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 100%|██████████| 174/174 [00:10<00:00, 15.85it/s]

# %% [markdown]
# Plot a GT/prediction example

# %%
plot_img_label(X_val[0],Y_val[0], lbl_title="label GT")
plot_img_label(X_val[0],Y_val_pred[0], lbl_title="label Pred")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Choose several IoU thresholds $\tau$ that might be of interest and for each compute matching statistics for the validation data.

# %%
taus = [0.01, 0.1, 0.15, 0.2, 0.25]
stats = [matching_dataset(Y_val, Y_val_pred, thresh=t, show_progress=False) for t in tqdm(taus)]
# Out:
# 100%|██████████| 5/5 [00:02<00:00,  2.40it/s]

# %%
stats[0]
# Out:
# DatasetMatching(criterion='iou', thresh=0.01, fp=593, tp=440, fn=340, precision=0.4259438528557599, recall=0.5641025641025641, accuracy=0.32046613255644574, f1=0.4853833425261997, n_true=780, n_pred=1033, mean_true_score=0.4194735946515814, mean_matched_score=0.7436122814278033, panoptic_quality=0.36093701470296025, by_image=False)

# %% [markdown]
# Example: Print all available matching statistics for $\tau=0.5$

# %%
stats[taus.index(0.25)]
# Out:
# DatasetMatching(criterion='iou', thresh=0.25, fp=599, tp=434, fn=346, precision=0.42013552758954503, recall=0.5564102564102564, accuracy=0.3147208121827411, f1=0.47876447876447875, n_true=780, n_pred=1033, mean_true_score=0.4183664818604787, mean_matched_score=0.7519028936662981, panoptic_quality=0.35998439696764856, by_image=False)

# %% [markdown]
# Plot the matching statistics and the number of true/false positives/negatives as a function of the IoU threshold $\tau$.

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(15,5))

for m in ('precision', 'recall', 'accuracy', 'f1', 'mean_true_score', 'mean_matched_score', 'panoptic_quality'):
    ax1.plot(taus, [s._asdict()[m] for s in stats], '.-', lw=2, label=m)
ax1.set_xlabel(r'IoU threshold $\tau$')
ax1.set_ylabel('Metric value')
ax1.grid()
ax1.legend()

for m in ('fp', 'tp', 'fn'):
    ax2.plot(taus, [s._asdict()[m] for s in stats], '.-', lw=2, label=m)
ax2.set_xlabel(r'IoU threshold $\tau$')
ax2.set_ylabel('Number #')
ax2.grid()
ax2.legend();
